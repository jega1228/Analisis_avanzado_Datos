# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 60 # número mínimo de fotos por personaje para filtrar la base
resize=0.5 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1348
# Classes: 8
# Dimentions: (62, 47)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1078, 2914)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (270, 2914)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1078, 8)
# (270, 8)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               1661550
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 768
# =================================================================
# Total params: 1,716,563
# Trainable params: 1,716,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.344, max:    0.888, cur:    0.888)
# 	validation       	 (min:    0.363, max:    0.815, cur:    0.785)
# Loss
# 	training         	 (min:    0.421, max:    1.928, cur:    0.421)
# 	validation       	 (min:    0.668, max:    1.832, cur:    0.668)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6685 - accuracy: 0.7852

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 1

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F9DBC484C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001F9DA6F3318> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [256, 64], 'epochs': 60, 'batch_size': 168}
# 0.769055036344756

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(256, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(64, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               746240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 763,208
# Trainable params: 763,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 168 # Tamaño de la ventana
epoc = 60 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.367, max:    0.853, cur:    0.848)
# 	validation       	 (min:    0.363, max:    0.804, cur:    0.778)
# Loss
# 	training         	 (min:    0.527, max:    1.895, cur:    0.545)
# 	validation       	 (min:    0.710, max:    1.813, cur:    0.710)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.7100 - accuracy: 0.7778

# %% [markdown]
# ### MODELO 3 - PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1078, 2914)
# (1078, 200)

# %%
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(580, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(100, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               116580
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 808
# =================================================================
# Total params: 175,488
# Trainable params: 175,488
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=100, batch_size=256, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 1.9421 - accuracy: 0.2828 - val_loss: 1.6617 - val_accuracy: 0.4074
# Epoch 2/100
# 4/4 - 0s - loss: 1.5203 - accuracy: 0.4487 - val_loss: 1.4650 - val_accuracy: 0.4938
# Epoch 3/100
# 4/4 - 0s - loss: 1.2372 - accuracy: 0.5797 - val_loss: 1.3126 - val_accuracy: 0.5926
# Epoch 4/100
# 4/4 - 0s - loss: 1.0186 - accuracy: 0.7085 - val_loss: 1.1385 - val_accuracy: 0.6235
# Epoch 5/100
# 4/4 - 0s - loss: 0.8431 - accuracy: 0.7817 - val_loss: 1.0328 - val_accuracy: 0.6667
# Epoch 6/100
# 4/4 - 0s - loss: 0.6999 - accuracy: 0.8526 - val_loss: 0.9290 - val_accuracy: 0.7037
# Epoch 7/100
# 4/4 - 0s - loss: 0.5681 - accuracy: 0.9072 - val_loss: 0.8629 - val_accuracy: 0.7284
# Epoch 8/100
# 4/4 - 0s - loss: 0.4720 - accuracy: 0.9367 - val_loss: 0.8051 - val_accuracy: 0.7407
# Epoch 9/100
# 4/4 - 0s - loss: 0.3876 - accuracy: 0.9531 - val_loss: 0.7553 - val_accuracy: 0.7284
# Epoch 10/100
# 4/4 - 0s - loss: 0.3188 - accuracy: 0.9662 - val_loss: 0.7026 - val_accuracy: 0.7531
# Epoch 11/100
# 4/4 - 0s - loss: 0.2634 - accuracy: 0.9825 - val_loss: 0.6584 - val_accuracy: 0.7654
# Epoch 12/100
# 4/4 - 0s - loss: 0.2190 - accuracy: 0.9945 - val_loss: 0.6292 - val_accuracy: 0.7901
# Epoch 13/100
# 4/4 - 0s - loss: 0.1826 - accuracy: 0.9945 - val_loss: 0.6084 - val_accuracy: 0.7901
# Epoch 14/100
# 4/4 - 0s - loss: 0.1539 - accuracy: 0.9978 - val_loss: 0.5968 - val_accuracy: 0.7778
# Epoch 15/100
# 4/4 - 0s - loss: 0.1312 - accuracy: 0.9978 - val_loss: 0.5805 - val_accuracy: 0.7840
# Epoch 16/100
# 4/4 - 0s - loss: 0.1126 - accuracy: 0.9989 - val_loss: 0.5643 - val_accuracy: 0.8025
# Epoch 17/100
# 4/4 - 0s - loss: 0.0979 - accuracy: 0.9989 - val_loss: 0.5509 - val_accuracy: 0.8025
# Epoch 18/100
# 4/4 - 0s - loss: 0.0857 - accuracy: 1.0000 - val_loss: 0.5409 - val_accuracy: 0.8272
# Epoch 19/100
# 4/4 - 0s - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.5345 - val_accuracy: 0.8333
# Epoch 20/100
# 4/4 - 0s - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.5293 - val_accuracy: 0.8333
# Epoch 21/100
# 4/4 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.5266 - val_accuracy: 0.8395
# Epoch 22/100
# 4/4 - 0s - loss: 0.0555 - accuracy: 1.0000 - val_loss: 0.5240 - val_accuracy: 0.8395
# Epoch 23/100
# 4/4 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 0.5229 - val_accuracy: 0.8395
# Epoch 24/100
# 4/4 - 0s - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.8395
# Epoch 25/100
# 4/4 - 0s - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.5165 - val_accuracy: 0.8395
# Epoch 26/100
# 4/4 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.8519
# Epoch 27/100
# 4/4 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.8519
# Epoch 28/100
# 4/4 - 0s - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.5092 - val_accuracy: 0.8519
# Epoch 29/100
# 4/4 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.5079 - val_accuracy: 0.8519
# Epoch 30/100
# 4/4 - 0s - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.8519
# Epoch 31/100
# 4/4 - 0s - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.5085 - val_accuracy: 0.8395
# Epoch 32/100
# 4/4 - 0s - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.5078 - val_accuracy: 0.8395
# Epoch 33/100
# 4/4 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.5067 - val_accuracy: 0.8395
# Epoch 34/100
# 4/4 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.5061 - val_accuracy: 0.8457
# Epoch 35/100
# 4/4 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.5048 - val_accuracy: 0.8457
# Epoch 36/100
# 4/4 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8457
# Epoch 37/100
# 4/4 - 0s - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.5042 - val_accuracy: 0.8457
# Epoch 38/100
# 4/4 - 0s - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.8457
# Epoch 39/100
# 4/4 - 0s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8457
# Epoch 40/100
# 4/4 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8457
# Epoch 41/100
# 4/4 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.8457
# Epoch 42/100
# 4/4 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.5039 - val_accuracy: 0.8457
# Epoch 43/100
# 4/4 - 0s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.8457
# Epoch 44/100
# 4/4 - 0s - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.5038 - val_accuracy: 0.8457
# Epoch 45/100
# 4/4 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.8457
# Epoch 46/100
# 4/4 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8457
# Epoch 47/100
# 4/4 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.8457
# Epoch 48/100
# 4/4 - 0s - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.8457
# Epoch 49/100
# 4/4 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8457
# Epoch 50/100
# 4/4 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.5035 - val_accuracy: 0.8457
# Epoch 51/100
# 4/4 - 0s - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.5031 - val_accuracy: 0.8457
# Epoch 52/100
# 4/4 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.8457
# Epoch 53/100
# 4/4 - 0s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.5026 - val_accuracy: 0.8457
# Epoch 54/100
# 4/4 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.8457
# Epoch 55/100
# 4/4 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.5032 - val_accuracy: 0.8457
# Epoch 56/100
# 4/4 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8457
# Epoch 57/100
# 4/4 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5036 - val_accuracy: 0.8457
# Epoch 58/100
# 4/4 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.8457
# Epoch 59/100
# 4/4 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5041 - val_accuracy: 0.8457
# Epoch 60/100
# 4/4 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5045 - val_accuracy: 0.8457
# Epoch 61/100
# 4/4 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5049 - val_accuracy: 0.8457
# Epoch 62/100
# 4/4 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5050 - val_accuracy: 0.8457
# Epoch 63/100
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5054 - val_accuracy: 0.8457
# Epoch 64/100
# 4/4 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.5056 - val_accuracy: 0.8457
# Epoch 65/100
# 4/4 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8457
# Epoch 66/100
# 4/4 - 0s - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.5055 - val_accuracy: 0.8457
# Epoch 67/100
# 4/4 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5056 - val_accuracy: 0.8457
# Epoch 68/100
# 4/4 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.8457
# Epoch 69/100
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5060 - val_accuracy: 0.8457
# Epoch 70/100
# 4/4 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5065 - val_accuracy: 0.8395
# Epoch 71/100
# 4/4 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5066 - val_accuracy: 0.8395
# Epoch 72/100
# 4/4 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.8395
# Epoch 73/100
# 4/4 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.8395
# Epoch 74/100
# 4/4 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5077 - val_accuracy: 0.8395
# Epoch 75/100
# 4/4 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5082 - val_accuracy: 0.8395
# Epoch 76/100
# 4/4 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5088 - val_accuracy: 0.8395
# Epoch 77/100
# 4/4 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8395
# Epoch 78/100
# 4/4 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.8395
# Epoch 79/100
# 4/4 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5095 - val_accuracy: 0.8395
# Epoch 80/100
# 4/4 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8395
# Epoch 81/100
# 4/4 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8395
# Epoch 82/100
# 4/4 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5096 - val_accuracy: 0.8395
# Epoch 83/100
# 4/4 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.8395
# Epoch 84/100
# 4/4 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5107 - val_accuracy: 0.8395
# Epoch 85/100
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.8395
# Epoch 86/100
# 4/4 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5113 - val_accuracy: 0.8395
# Epoch 87/100
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5117 - val_accuracy: 0.8395
# Epoch 88/100
# 4/4 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5121 - val_accuracy: 0.8395
# Epoch 89/100
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.5127 - val_accuracy: 0.8395
# Epoch 90/100
# 4/4 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5132 - val_accuracy: 0.8395
# Epoch 91/100
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.8395
# Epoch 92/100
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.5142 - val_accuracy: 0.8395
# Epoch 93/100
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.5145 - val_accuracy: 0.8395
# Epoch 94/100
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.8457
# Epoch 95/100
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8457
# Epoch 96/100
# 4/4 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5153 - val_accuracy: 0.8457
# Epoch 97/100
# 4/4 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.8457
# Epoch 98/100
# 4/4 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5157 - val_accuracy: 0.8457
# Epoch 99/100
# 4/4 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.8457
# Epoch 100/100
# 4/4 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5162 - val_accuracy: 0.8457

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 997us/step - loss: 0.4617 - accuracy: 0.8481

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
