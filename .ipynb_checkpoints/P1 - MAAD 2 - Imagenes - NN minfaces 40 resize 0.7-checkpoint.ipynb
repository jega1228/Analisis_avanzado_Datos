# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 40 # número mínimo de fotos por personaje para filtrar la base
resize=0.5 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1867
# Classes: 19
# Dimentions: (62, 47)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1493, 2914)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (374, 2914)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1493, 19)
# (374, 19)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(128, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               1492480
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 1,560,595
# Trainable params: 1,560,595
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 60 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.264, max:    0.894, cur:    0.894)
# 	validation       	 (min:    0.283, max:    0.773, cur:    0.733)
# Loss
# 	training         	 (min:    0.426, max:    2.648, cur:    0.426)
# 	validation       	 (min:    0.870, max:    2.526, cur:    0.931)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9312 - accuracy: 0.7326

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 128],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 2

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [580, 100], 'epochs': 50, 'batch_size': 50}
# 0.7126890380313199

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(580, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(100, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               1690700
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                1919
# =================================================================
# Total params: 1,750,719
# Trainable params: 1,750,719
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 98 # Tamaño de la ventana
epoc = 60 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.264, max:    0.887, cur:    0.884)
# 	validation       	 (min:    0.283, max:    0.765, cur:    0.757)
# Loss
# 	training         	 (min:    0.464, max:    2.622, cur:    0.475)
# 	validation       	 (min:    0.871, max:    2.530, cur:    0.871)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8710 - accuracy: 0.7567

# %% [markdown]
# ### MODELO 3 - PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
pca = PCA(n_components=1493)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
NCOMPONENTS = 100

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1493, 2914)
# (1493, 100)

# %%
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(580, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(100, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               58580
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                1919
# =================================================================
# Total params: 118,599
# Trainable params: 118,599
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=100, batch_size=256, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/100
# 5/5 - 1s - loss: 2.7845 - accuracy: 0.2183 - val_loss: 2.4327 - val_accuracy: 0.2812
# Epoch 2/100
# 5/5 - 0s - loss: 2.2593 - accuracy: 0.3176 - val_loss: 2.1914 - val_accuracy: 0.3348
# Epoch 3/100
# 5/5 - 0s - loss: 1.9560 - accuracy: 0.4224 - val_loss: 2.0147 - val_accuracy: 0.3929
# Epoch 4/100
# 5/5 - 0s - loss: 1.7451 - accuracy: 0.5114 - val_loss: 1.8265 - val_accuracy: 0.4464
# Epoch 5/100
# 5/5 - 0s - loss: 1.5291 - accuracy: 0.5863 - val_loss: 1.6876 - val_accuracy: 0.4777
# Epoch 6/100
# 5/5 - 0s - loss: 1.3582 - accuracy: 0.6383 - val_loss: 1.5627 - val_accuracy: 0.5670
# Epoch 7/100
# 5/5 - 0s - loss: 1.2070 - accuracy: 0.7218 - val_loss: 1.4612 - val_accuracy: 0.6339
# Epoch 8/100
# 5/5 - 0s - loss: 1.0740 - accuracy: 0.7738 - val_loss: 1.3715 - val_accuracy: 0.6696
# Epoch 9/100
# 5/5 - 0s - loss: 0.9559 - accuracy: 0.8219 - val_loss: 1.2959 - val_accuracy: 0.6786
# Epoch 10/100
# 5/5 - 0s - loss: 0.8559 - accuracy: 0.8519 - val_loss: 1.2341 - val_accuracy: 0.7054
# Epoch 11/100
# 5/5 - 0s - loss: 0.7655 - accuracy: 0.8826 - val_loss: 1.1888 - val_accuracy: 0.7098
# Epoch 12/100
# 5/5 - 0s - loss: 0.6855 - accuracy: 0.9054 - val_loss: 1.1475 - val_accuracy: 0.7321
# Epoch 13/100
# 5/5 - 0s - loss: 0.6155 - accuracy: 0.9228 - val_loss: 1.1076 - val_accuracy: 0.7500
# Epoch 14/100
# 5/5 - 0s - loss: 0.5538 - accuracy: 0.9401 - val_loss: 1.0773 - val_accuracy: 0.7589
# Epoch 15/100
# 5/5 - 0s - loss: 0.4979 - accuracy: 0.9488 - val_loss: 1.0532 - val_accuracy: 0.7589
# Epoch 16/100
# 5/5 - 0s - loss: 0.4474 - accuracy: 0.9567 - val_loss: 1.0299 - val_accuracy: 0.7500
# Epoch 17/100
# 5/5 - 0s - loss: 0.4029 - accuracy: 0.9669 - val_loss: 1.0082 - val_accuracy: 0.7545
# Epoch 18/100
# 5/5 - 0s - loss: 0.3639 - accuracy: 0.9740 - val_loss: 0.9916 - val_accuracy: 0.7500
# Epoch 19/100
# 5/5 - 0s - loss: 0.3286 - accuracy: 0.9787 - val_loss: 0.9774 - val_accuracy: 0.7545
# Epoch 20/100
# 5/5 - 0s - loss: 0.2971 - accuracy: 0.9835 - val_loss: 0.9663 - val_accuracy: 0.7634
# Epoch 21/100
# 5/5 - 0s - loss: 0.2695 - accuracy: 0.9890 - val_loss: 0.9546 - val_accuracy: 0.7589
# Epoch 22/100
# 5/5 - 0s - loss: 0.2449 - accuracy: 0.9905 - val_loss: 0.9461 - val_accuracy: 0.7768
# Epoch 23/100
# 5/5 - 0s - loss: 0.2223 - accuracy: 0.9937 - val_loss: 0.9378 - val_accuracy: 0.7634
# Epoch 24/100
# 5/5 - 0s - loss: 0.2023 - accuracy: 0.9937 - val_loss: 0.9285 - val_accuracy: 0.7679
# Epoch 25/100
# 5/5 - 0s - loss: 0.1851 - accuracy: 0.9953 - val_loss: 0.9198 - val_accuracy: 0.7723
# Epoch 26/100
# 5/5 - 0s - loss: 0.1698 - accuracy: 0.9968 - val_loss: 0.9170 - val_accuracy: 0.7768
# Epoch 27/100
# 5/5 - 0s - loss: 0.1561 - accuracy: 0.9968 - val_loss: 0.9119 - val_accuracy: 0.7723
# Epoch 28/100
# 5/5 - 0s - loss: 0.1439 - accuracy: 0.9976 - val_loss: 0.9092 - val_accuracy: 0.7723
# Epoch 29/100
# 5/5 - 0s - loss: 0.1335 - accuracy: 0.9976 - val_loss: 0.9058 - val_accuracy: 0.7679
# Epoch 30/100
# 5/5 - 0s - loss: 0.1237 - accuracy: 0.9992 - val_loss: 0.9005 - val_accuracy: 0.7679
# Epoch 31/100
# 5/5 - 0s - loss: 0.1151 - accuracy: 0.9992 - val_loss: 0.9000 - val_accuracy: 0.7723
# Epoch 32/100
# 5/5 - 0s - loss: 0.1075 - accuracy: 0.9992 - val_loss: 0.8971 - val_accuracy: 0.7723
# Epoch 33/100
# 5/5 - 0s - loss: 0.1005 - accuracy: 0.9992 - val_loss: 0.8958 - val_accuracy: 0.7723
# Epoch 34/100
# 5/5 - 0s - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.8936 - val_accuracy: 0.7723
# Epoch 35/100
# 5/5 - 0s - loss: 0.0886 - accuracy: 1.0000 - val_loss: 0.8904 - val_accuracy: 0.7723
# Epoch 36/100
# 5/5 - 0s - loss: 0.0834 - accuracy: 1.0000 - val_loss: 0.8873 - val_accuracy: 0.7768
# Epoch 37/100
# 5/5 - 0s - loss: 0.0788 - accuracy: 1.0000 - val_loss: 0.8881 - val_accuracy: 0.7723
# Epoch 38/100
# 5/5 - 0s - loss: 0.0745 - accuracy: 1.0000 - val_loss: 0.8872 - val_accuracy: 0.7768
# Epoch 39/100
# 5/5 - 0s - loss: 0.0705 - accuracy: 1.0000 - val_loss: 0.8861 - val_accuracy: 0.7768
# Epoch 40/100
# 5/5 - 0s - loss: 0.0668 - accuracy: 1.0000 - val_loss: 0.8839 - val_accuracy: 0.7768
# Epoch 41/100
# 5/5 - 0s - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.8818 - val_accuracy: 0.7723
# Epoch 42/100
# 5/5 - 0s - loss: 0.0604 - accuracy: 1.0000 - val_loss: 0.8814 - val_accuracy: 0.7723
# Epoch 43/100
# 5/5 - 0s - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.8823 - val_accuracy: 0.7723
# Epoch 44/100
# 5/5 - 0s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 0.8813 - val_accuracy: 0.7723
# Epoch 45/100
# 5/5 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.8815 - val_accuracy: 0.7768
# Epoch 46/100
# 5/5 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 0.8794 - val_accuracy: 0.7768
# Epoch 47/100
# 5/5 - 0s - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.8790 - val_accuracy: 0.7768
# Epoch 48/100
# 5/5 - 0s - loss: 0.0459 - accuracy: 1.0000 - val_loss: 0.8782 - val_accuracy: 0.7768
# Epoch 49/100
# 5/5 - 0s - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.8788 - val_accuracy: 0.7723
# Epoch 50/100
# 5/5 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.8789 - val_accuracy: 0.7723
# Epoch 51/100
# 5/5 - 0s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 0.8791 - val_accuracy: 0.7723
# Epoch 52/100
# 5/5 - 0s - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.8787 - val_accuracy: 0.7723
# Epoch 53/100
# 5/5 - 0s - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.8777 - val_accuracy: 0.7723
# Epoch 54/100
# 5/5 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.8766 - val_accuracy: 0.7723
# Epoch 55/100
# 5/5 - 0s - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.8766 - val_accuracy: 0.7723
# Epoch 56/100
# 5/5 - 0s - loss: 0.0337 - accuracy: 1.0000 - val_loss: 0.8770 - val_accuracy: 0.7723
# Epoch 57/100
# 5/5 - 0s - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.8783 - val_accuracy: 0.7723
# Epoch 58/100
# 5/5 - 0s - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.8788 - val_accuracy: 0.7723
# Epoch 59/100
# 5/5 - 0s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.8787 - val_accuracy: 0.7723
# Epoch 60/100
# 5/5 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.8793 - val_accuracy: 0.7634
# Epoch 61/100
# 5/5 - 0s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.8792 - val_accuracy: 0.7634
# Epoch 62/100
# 5/5 - 0s - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.8793 - val_accuracy: 0.7634
# Epoch 63/100
# 5/5 - 0s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.8797 - val_accuracy: 0.7634
# Epoch 64/100
# 5/5 - 0s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.8808 - val_accuracy: 0.7634
# Epoch 65/100
# 5/5 - 0s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.8814 - val_accuracy: 0.7634
# Epoch 66/100
# 5/5 - 0s - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.7634
# Epoch 67/100
# 5/5 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.7634
# Epoch 68/100
# 5/5 - 0s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.8818 - val_accuracy: 0.7634
# Epoch 69/100
# 5/5 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.8826 - val_accuracy: 0.7634
# Epoch 70/100
# 5/5 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.8834 - val_accuracy: 0.7634
# Epoch 71/100
# 5/5 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.8831 - val_accuracy: 0.7634
# Epoch 72/100
# 5/5 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.8839 - val_accuracy: 0.7634
# Epoch 73/100
# 5/5 - 0s - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.8849 - val_accuracy: 0.7589
# Epoch 74/100
# 5/5 - 0s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.8854 - val_accuracy: 0.7589
# Epoch 75/100
# 5/5 - 0s - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.7634
# Epoch 76/100
# 5/5 - 0s - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.8849 - val_accuracy: 0.7634
# Epoch 77/100
# 5/5 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.7589
# Epoch 78/100
# 5/5 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.8857 - val_accuracy: 0.7589
# Epoch 79/100
# 5/5 - 0s - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.8866 - val_accuracy: 0.7589
# Epoch 80/100
# 5/5 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.8871 - val_accuracy: 0.7634
# Epoch 81/100
# 5/5 - 0s - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.8871 - val_accuracy: 0.7589
# Epoch 82/100
# 5/5 - 0s - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.8882 - val_accuracy: 0.7589
# Epoch 83/100
# 5/5 - 0s - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.8887 - val_accuracy: 0.7589
# Epoch 84/100
# 5/5 - 0s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 0.8889 - val_accuracy: 0.7589
# Epoch 85/100
# 5/5 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.8889 - val_accuracy: 0.7634
# Epoch 86/100
# 5/5 - 0s - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.8894 - val_accuracy: 0.7679
# Epoch 87/100
# 5/5 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.8892 - val_accuracy: 0.7679
# Epoch 88/100
# 5/5 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.8894 - val_accuracy: 0.7679
# Epoch 89/100
# 5/5 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.8902 - val_accuracy: 0.7679
# Epoch 90/100
# 5/5 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.8906 - val_accuracy: 0.7634
# Epoch 91/100
# 5/5 - 0s - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.8916 - val_accuracy: 0.7634
# Epoch 92/100
# 5/5 - 0s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.8920 - val_accuracy: 0.7634
# Epoch 93/100
# 5/5 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.8928 - val_accuracy: 0.7634
# Epoch 94/100
# 5/5 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.8930 - val_accuracy: 0.7634
# Epoch 95/100
# 5/5 - 0s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.8934 - val_accuracy: 0.7634
# Epoch 96/100
# 5/5 - 0s - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.8936 - val_accuracy: 0.7679
# Epoch 97/100
# 5/5 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 0.8942 - val_accuracy: 0.7679
# Epoch 98/100
# 5/5 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.8945 - val_accuracy: 0.7679
# Epoch 99/100
# 5/5 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.7679
# Epoch 100/100
# 5/5 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.8952 - val_accuracy: 0.7634

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8017 - accuracy: 0.7914

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
