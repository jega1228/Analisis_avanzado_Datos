# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 70 # número mínimo de fotos por personaje para filtrar la base
resize=0.5 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1288
# Classes: 7
# Dimentions: (62, 47)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1030, 2914)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (258, 2914)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1030, 7)
# (258, 7)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               1661550
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 672
# =================================================================
# Total params: 1,716,467
# Trainable params: 1,716,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.332, max:    0.882, cur:    0.882)
# 	validation       	 (min:    0.461, max:    0.841, cur:    0.841)
# Loss
# 	training         	 (min:    0.467, max:    1.868, cur:    0.467)
# 	validation       	 (min:    0.591, max:    1.587, cur:    0.591)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5905 - accuracy: 0.8411

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 2

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000200525D7288> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000200587FA5E8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [512, 128], 'epochs': 50, 'batch_size': 50}
# 0.7834951456310679

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(128, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               1492480
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 1,559,047
# Trainable params: 1,559,047
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 50 # Tamaño de la ventana
epoc = 50 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.377, max:    0.937, cur:    0.937)
# 	validation       	 (min:    0.461, max:    0.853, cur:    0.806)
# Loss
# 	training         	 (min:    0.225, max:    1.784, cur:    0.225)
# 	validation       	 (min:    0.523, max:    1.627, cur:    0.647)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.6469 - accuracy: 0.8062

# %% [markdown]
# ### MODELO 3 - PCA

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1030, 2914)
# (1030, 200)

# %%
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(580, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(100, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               116580
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 707
# =================================================================
# Total params: 175,387
# Trainable params: 175,387
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=100, batch_size=256, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/100
# 4/4 - 1s - loss: 1.9317 - accuracy: 0.2777 - val_loss: 1.5018 - val_accuracy: 0.4387
# Epoch 2/100
# 4/4 - 0s - loss: 1.3807 - accuracy: 0.4926 - val_loss: 1.2971 - val_accuracy: 0.5548
# Epoch 3/100
# 4/4 - 0s - loss: 1.1487 - accuracy: 0.6011 - val_loss: 1.1716 - val_accuracy: 0.5742
# Epoch 4/100
# 4/4 - 0s - loss: 0.9349 - accuracy: 0.7051 - val_loss: 1.0749 - val_accuracy: 0.6452
# Epoch 5/100
# 4/4 - 0s - loss: 0.7649 - accuracy: 0.8091 - val_loss: 0.9620 - val_accuracy: 0.6774
# Epoch 6/100
# 4/4 - 0s - loss: 0.6326 - accuracy: 0.8766 - val_loss: 0.8670 - val_accuracy: 0.7290
# Epoch 7/100
# 4/4 - 0s - loss: 0.5117 - accuracy: 0.9086 - val_loss: 0.8003 - val_accuracy: 0.7226
# Epoch 8/100
# 4/4 - 0s - loss: 0.4118 - accuracy: 0.9429 - val_loss: 0.7333 - val_accuracy: 0.7548
# Epoch 9/100
# 4/4 - 0s - loss: 0.3356 - accuracy: 0.9646 - val_loss: 0.6791 - val_accuracy: 0.7548
# Epoch 10/100
# 4/4 - 0s - loss: 0.2764 - accuracy: 0.9794 - val_loss: 0.6466 - val_accuracy: 0.7742
# Epoch 11/100
# 4/4 - 0s - loss: 0.2238 - accuracy: 0.9897 - val_loss: 0.6305 - val_accuracy: 0.8000
# Epoch 12/100
# 4/4 - 0s - loss: 0.1845 - accuracy: 0.9931 - val_loss: 0.6242 - val_accuracy: 0.8000
# Epoch 13/100
# 4/4 - 0s - loss: 0.1537 - accuracy: 0.9954 - val_loss: 0.6117 - val_accuracy: 0.8065
# Epoch 14/100
# 4/4 - 0s - loss: 0.1294 - accuracy: 0.9977 - val_loss: 0.5929 - val_accuracy: 0.8194
# Epoch 15/100
# 4/4 - 0s - loss: 0.1093 - accuracy: 0.9989 - val_loss: 0.5794 - val_accuracy: 0.8258
# Epoch 16/100
# 4/4 - 0s - loss: 0.0948 - accuracy: 0.9989 - val_loss: 0.5718 - val_accuracy: 0.8258
# Epoch 17/100
# 4/4 - 0s - loss: 0.0826 - accuracy: 0.9989 - val_loss: 0.5693 - val_accuracy: 0.8387
# Epoch 18/100
# 4/4 - 0s - loss: 0.0726 - accuracy: 0.9989 - val_loss: 0.5671 - val_accuracy: 0.8387
# Epoch 19/100
# 4/4 - 0s - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.5663 - val_accuracy: 0.8387
# Epoch 20/100
# 4/4 - 0s - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.5637 - val_accuracy: 0.8323
# Epoch 21/100
# 4/4 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8323
# Epoch 22/100
# 4/4 - 0s - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.5585 - val_accuracy: 0.8323
# Epoch 23/100
# 4/4 - 0s - loss: 0.0442 - accuracy: 1.0000 - val_loss: 0.5562 - val_accuracy: 0.8323
# Epoch 24/100
# 4/4 - 0s - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 0.8323
# Epoch 25/100
# 4/4 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8323
# Epoch 26/100
# 4/4 - 0s - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.8323
# Epoch 27/100
# 4/4 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.8323
# Epoch 28/100
# 4/4 - 0s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 0.5515 - val_accuracy: 0.8323
# Epoch 29/100
# 4/4 - 0s - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.8323
# Epoch 30/100
# 4/4 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.5521 - val_accuracy: 0.8323
# Epoch 31/100
# 4/4 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8323
# Epoch 32/100
# 4/4 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.8323
# Epoch 33/100
# 4/4 - 0s - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.5544 - val_accuracy: 0.8323
# Epoch 34/100
# 4/4 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.8323
# Epoch 35/100
# 4/4 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 0.8323
# Epoch 36/100
# 4/4 - 0s - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.5533 - val_accuracy: 0.8323
# Epoch 37/100
# 4/4 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8323
# Epoch 38/100
# 4/4 - 0s - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 0.8323
# Epoch 39/100
# 4/4 - 0s - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8323
# Epoch 40/100
# 4/4 - 0s - loss: 0.0170 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.8323
# Epoch 41/100
# 4/4 - 0s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.5531 - val_accuracy: 0.8323
# Epoch 42/100
# 4/4 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.5533 - val_accuracy: 0.8323
# Epoch 43/100
# 4/4 - 0s - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.5531 - val_accuracy: 0.8323
# Epoch 44/100
# 4/4 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.5532 - val_accuracy: 0.8323
# Epoch 45/100
# 4/4 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8323
# Epoch 46/100
# 4/4 - 0s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 0.5534 - val_accuracy: 0.8323
# Epoch 47/100
# 4/4 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8323
# Epoch 48/100
# 4/4 - 0s - loss: 0.0127 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8323
# Epoch 49/100
# 4/4 - 0s - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.8323
# Epoch 50/100
# 4/4 - 0s - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8323
# Epoch 51/100
# 4/4 - 0s - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.8323
# Epoch 52/100
# 4/4 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.5535 - val_accuracy: 0.8323
# Epoch 53/100
# 4/4 - 0s - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8323
# Epoch 54/100
# 4/4 - 0s - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.8323
# Epoch 55/100
# 4/4 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.5537 - val_accuracy: 0.8323
# Epoch 56/100
# 4/4 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5539 - val_accuracy: 0.8323
# Epoch 57/100
# 4/4 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.8387
# Epoch 58/100
# 4/4 - 0s - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.5540 - val_accuracy: 0.8387
# Epoch 59/100
# 4/4 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5541 - val_accuracy: 0.8387
# Epoch 60/100
# 4/4 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.8387
# Epoch 61/100
# 4/4 - 0s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.8387
# Epoch 62/100
# 4/4 - 0s - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.5544 - val_accuracy: 0.8387
# Epoch 63/100
# 4/4 - 0s - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.5545 - val_accuracy: 0.8387
# Epoch 64/100
# 4/4 - 0s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.5550 - val_accuracy: 0.8452
# Epoch 65/100
# 4/4 - 0s - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.5553 - val_accuracy: 0.8452
# Epoch 66/100
# 4/4 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5559 - val_accuracy: 0.8452
# Epoch 67/100
# 4/4 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5561 - val_accuracy: 0.8452
# Epoch 68/100
# 4/4 - 0s - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.5564 - val_accuracy: 0.8452
# Epoch 69/100
# 4/4 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5565 - val_accuracy: 0.8452
# Epoch 70/100
# 4/4 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5563 - val_accuracy: 0.8452
# Epoch 71/100
# 4/4 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5562 - val_accuracy: 0.8452
# Epoch 72/100
# 4/4 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8452
# Epoch 73/100
# 4/4 - 0s - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5560 - val_accuracy: 0.8452
# Epoch 74/100
# 4/4 - 0s - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5562 - val_accuracy: 0.8452
# Epoch 75/100
# 4/4 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.5565 - val_accuracy: 0.8452
# Epoch 76/100
# 4/4 - 0s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5569 - val_accuracy: 0.8452
# Epoch 77/100
# 4/4 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5570 - val_accuracy: 0.8452
# Epoch 78/100
# 4/4 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5574 - val_accuracy: 0.8452
# Epoch 79/100
# 4/4 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.5577 - val_accuracy: 0.8452
# Epoch 80/100
# 4/4 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5581 - val_accuracy: 0.8452
# Epoch 81/100
# 4/4 - 0s - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.5585 - val_accuracy: 0.8452
# Epoch 82/100
# 4/4 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5591 - val_accuracy: 0.8452
# Epoch 83/100
# 4/4 - 0s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.5598 - val_accuracy: 0.8452
# Epoch 84/100
# 4/4 - 0s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5603 - val_accuracy: 0.8452
# Epoch 85/100
# 4/4 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8452
# Epoch 86/100
# 4/4 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.5610 - val_accuracy: 0.8452
# Epoch 87/100
# 4/4 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5612 - val_accuracy: 0.8452
# Epoch 88/100
# 4/4 - 0s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5613 - val_accuracy: 0.8452
# Epoch 89/100
# 4/4 - 0s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.5612 - val_accuracy: 0.8452
# Epoch 90/100
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.5611 - val_accuracy: 0.8452
# Epoch 91/100
# 4/4 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.5612 - val_accuracy: 0.8452
# Epoch 92/100
# 4/4 - 0s - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5614 - val_accuracy: 0.8452
# Epoch 93/100
# 4/4 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.5616 - val_accuracy: 0.8452
# Epoch 94/100
# 4/4 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5618 - val_accuracy: 0.8516
# Epoch 95/100
# 4/4 - 0s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5622 - val_accuracy: 0.8516
# Epoch 96/100
# 4/4 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.8516
# Epoch 97/100
# 4/4 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.8516
# Epoch 98/100
# 4/4 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.5631 - val_accuracy: 0.8516
# Epoch 99/100
# 4/4 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.5634 - val_accuracy: 0.8516
# Epoch 100/100
# 4/4 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.5636 - val_accuracy: 0.8516

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5208 - accuracy: 0.8721

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
