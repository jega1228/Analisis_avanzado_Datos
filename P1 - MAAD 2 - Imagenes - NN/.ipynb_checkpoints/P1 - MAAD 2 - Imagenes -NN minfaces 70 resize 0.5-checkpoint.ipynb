# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 70 # número mínimo de fotos por personaje para filtrar la base
resize=0.5 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1288
# Classes: 7
# Dimentions: (62, 47)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1030, 2914)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (258, 2914)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1030, 7)
# (258, 7)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               1661550
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 672
# =================================================================
# Total params: 1,716,467
# Trainable params: 1,716,467
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.347, max:    0.841, cur:    0.841)
# 	validation       	 (min:    0.461, max:    0.833, cur:    0.833)
# Loss
# 	training         	 (min:    0.530, max:    1.870, cur:    0.530)
# 	validation       	 (min:    0.624, max:    1.611, cur:    0.632)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6317 - accuracy: 0.8333

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128],[350,35]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 2

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [256, 64], 'epochs': 60, 'batch_size': 184}
# 0.5553398058252428

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(256, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(64, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               746240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 763,143
# Trainable params: 763,143
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 128 # Tamaño de la ventana
epoc = 60 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.366, max:    0.825, cur:    0.798)
# 	validation       	 (min:    0.461, max:    0.829, cur:    0.787)
# Loss
# 	training         	 (min:    0.555, max:    1.762, cur:    0.641)
# 	validation       	 (min:    0.631, max:    1.643, cur:    0.636)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6360 - accuracy: 0.7868

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1030, 2914)
# (1030, 200)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(256, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(64, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               51456
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 68,359
# Trainable params: 68,359
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=epoc, batch_size=size, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/60
# 7/7 - 1s - loss: 1.8310 - accuracy: 0.3029 - val_loss: 1.5809 - val_accuracy: 0.4065
# Epoch 2/60
# 7/7 - 0s - loss: 1.4437 - accuracy: 0.4651 - val_loss: 1.4054 - val_accuracy: 0.4452
# Epoch 3/60
# 7/7 - 0s - loss: 1.2231 - accuracy: 0.5623 - val_loss: 1.2854 - val_accuracy: 0.4839
# Epoch 4/60
# 7/7 - 0s - loss: 1.0364 - accuracy: 0.6629 - val_loss: 1.1892 - val_accuracy: 0.5742
# Epoch 5/60
# 7/7 - 0s - loss: 0.8763 - accuracy: 0.7646 - val_loss: 1.0843 - val_accuracy: 0.6129
# Epoch 6/60
# 7/7 - 0s - loss: 0.7353 - accuracy: 0.8411 - val_loss: 0.9783 - val_accuracy: 0.6516
# Epoch 7/60
# 7/7 - 0s - loss: 0.6141 - accuracy: 0.8937 - val_loss: 0.8812 - val_accuracy: 0.7032
# Epoch 8/60
# 7/7 - 0s - loss: 0.5115 - accuracy: 0.9326 - val_loss: 0.8166 - val_accuracy: 0.7290
# Epoch 9/60
# 7/7 - 0s - loss: 0.4243 - accuracy: 0.9566 - val_loss: 0.7587 - val_accuracy: 0.7548
# Epoch 10/60
# 7/7 - 0s - loss: 0.3535 - accuracy: 0.9691 - val_loss: 0.7095 - val_accuracy: 0.8000
# Epoch 11/60
# 7/7 - 0s - loss: 0.2947 - accuracy: 0.9829 - val_loss: 0.6753 - val_accuracy: 0.7935
# Epoch 12/60
# 7/7 - 0s - loss: 0.2490 - accuracy: 0.9886 - val_loss: 0.6449 - val_accuracy: 0.8000
# Epoch 13/60
# 7/7 - 0s - loss: 0.2100 - accuracy: 0.9931 - val_loss: 0.6200 - val_accuracy: 0.7935
# Epoch 14/60
# 7/7 - 0s - loss: 0.1792 - accuracy: 0.9977 - val_loss: 0.5981 - val_accuracy: 0.8065
# Epoch 15/60
# 7/7 - 0s - loss: 0.1549 - accuracy: 0.9989 - val_loss: 0.5802 - val_accuracy: 0.8194
# Epoch 16/60
# 7/7 - 0s - loss: 0.1346 - accuracy: 0.9989 - val_loss: 0.5709 - val_accuracy: 0.8194
# Epoch 17/60
# 7/7 - 0s - loss: 0.1181 - accuracy: 0.9989 - val_loss: 0.5595 - val_accuracy: 0.8258
# Epoch 18/60
# 7/7 - 0s - loss: 0.1040 - accuracy: 0.9989 - val_loss: 0.5502 - val_accuracy: 0.8258
# Epoch 19/60
# 7/7 - 0s - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.5424 - val_accuracy: 0.8258
# Epoch 20/60
# 7/7 - 0s - loss: 0.0831 - accuracy: 1.0000 - val_loss: 0.5361 - val_accuracy: 0.8323
# Epoch 21/60
# 7/7 - 0s - loss: 0.0750 - accuracy: 1.0000 - val_loss: 0.5299 - val_accuracy: 0.8323
# Epoch 22/60
# 7/7 - 0s - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.5251 - val_accuracy: 0.8387
# Epoch 23/60
# 7/7 - 0s - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.5213 - val_accuracy: 0.8387
# Epoch 24/60
# 7/7 - 0s - loss: 0.0570 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.8387
# Epoch 25/60
# 7/7 - 0s - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.5155 - val_accuracy: 0.8387
# Epoch 26/60
# 7/7 - 0s - loss: 0.0487 - accuracy: 1.0000 - val_loss: 0.5114 - val_accuracy: 0.8387
# Epoch 27/60
# 7/7 - 0s - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.8387
# Epoch 28/60
# 7/7 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.8452
# Epoch 29/60
# 7/7 - 0s - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.5043 - val_accuracy: 0.8516
# Epoch 30/60
# 7/7 - 0s - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.5030 - val_accuracy: 0.8452
# Epoch 31/60
# 7/7 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.5021 - val_accuracy: 0.8452
# Epoch 32/60
# 7/7 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.5013 - val_accuracy: 0.8452
# Epoch 33/60
# 7/7 - 0s - loss: 0.0312 - accuracy: 1.0000 - val_loss: 0.4998 - val_accuracy: 0.8452
# Epoch 34/60
# 7/7 - 0s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.4976 - val_accuracy: 0.8452
# Epoch 35/60
# 7/7 - 0s - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.8452
# Epoch 36/60
# 7/7 - 0s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.4955 - val_accuracy: 0.8452
# Epoch 37/60
# 7/7 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.4953 - val_accuracy: 0.8452
# Epoch 38/60
# 7/7 - 0s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.4943 - val_accuracy: 0.8452
# Epoch 39/60
# 7/7 - 0s - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.8452
# Epoch 40/60
# 7/7 - 0s - loss: 0.0221 - accuracy: 1.0000 - val_loss: 0.4939 - val_accuracy: 0.8452
# Epoch 41/60
# 7/7 - 0s - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.8452
# Epoch 42/60
# 7/7 - 0s - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.4927 - val_accuracy: 0.8452
# Epoch 43/60
# 7/7 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.8452
# Epoch 44/60
# 7/7 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.4926 - val_accuracy: 0.8452
# Epoch 45/60
# 7/7 - 0s - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.4921 - val_accuracy: 0.8452
# Epoch 46/60
# 7/7 - 0s - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8452
# Epoch 47/60
# 7/7 - 0s - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8452
# Epoch 48/60
# 7/7 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8452
# Epoch 49/60
# 7/7 - 0s - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8452
# Epoch 50/60
# 7/7 - 0s - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.4913 - val_accuracy: 0.8452
# Epoch 51/60
# 7/7 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8452
# Epoch 52/60
# 7/7 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.4912 - val_accuracy: 0.8452
# Epoch 53/60
# 7/7 - 0s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8452
# Epoch 54/60
# 7/7 - 0s - loss: 0.0132 - accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.8452
# Epoch 55/60
# 7/7 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.4911 - val_accuracy: 0.8452
# Epoch 56/60
# 7/7 - 0s - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.4910 - val_accuracy: 0.8452
# Epoch 57/60
# 7/7 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8452
# Epoch 58/60
# 7/7 - 0s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.4917 - val_accuracy: 0.8452
# Epoch 59/60
# 7/7 - 0s - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8452
# Epoch 60/60
# 7/7 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.8387

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 873us/step - loss: 0.4745 - accuracy: 0.8566

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
