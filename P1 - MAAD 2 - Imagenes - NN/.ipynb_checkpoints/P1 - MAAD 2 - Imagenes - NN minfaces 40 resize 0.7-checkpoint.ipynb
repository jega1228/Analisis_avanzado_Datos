# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 40 # número mínimo de fotos por personaje para filtrar la base
resize=0.7 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1867
# Classes: 19
# Dimentions: (87, 65)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1493, 5655)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (374, 5655)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1493, 19)
# (374, 19)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(128, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               2895872
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 2,963,987
# Trainable params: 2,963,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 60 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.263, max:    0.709, cur:    0.709)
# 	validation       	 (min:    0.283, max:    0.674, cur:    0.636)
# Loss
# 	training         	 (min:    1.023, max:    2.663, cur:    1.023)
# 	validation       	 (min:    1.199, max:    2.544, cur:    1.199)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1989 - accuracy: 0.6364

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 128],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 2

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002413F65B558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002414590D828> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'sgd', 'hidden_layers': [512, 128], 'epochs': 50, 'batch_size': 150}
# 0.301427293064877

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(128, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               2895872
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 2,963,987
# Trainable params: 2,963,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 150 # Tamaño de la ventana
epoc = 50 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.238, max:    0.363, cur:    0.363)
# 	validation       	 (min:    0.283, max:    0.377, cur:    0.353)
# Loss
# 	training         	 (min:    2.224, max:    2.688, cur:    2.224)
# 	validation       	 (min:    2.231, max:    2.540, cur:    2.231)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2310 - accuracy: 0.3529

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1493)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 100

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1493, 5655)
# (1493, 100)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados

inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(512, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(128, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               51712
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                2451
# =================================================================
# Total params: 119,827
# Trainable params: 119,827
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=50, batch_size=150, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/50
# 9/9 - 1s - loss: 2.5345 - accuracy: 0.2766 - val_loss: 2.2606 - val_accuracy: 0.3170
# Epoch 2/50
# 9/9 - 0s - loss: 1.9188 - accuracy: 0.4082 - val_loss: 1.9030 - val_accuracy: 0.4375
# Epoch 3/50
# 9/9 - 0s - loss: 1.5548 - accuracy: 0.5603 - val_loss: 1.6505 - val_accuracy: 0.5312
# Epoch 4/50
# 9/9 - 0s - loss: 1.2619 - accuracy: 0.6887 - val_loss: 1.4678 - val_accuracy: 0.6071
# Epoch 5/50
# 9/9 - 0s - loss: 1.0310 - accuracy: 0.7872 - val_loss: 1.2953 - val_accuracy: 0.6786
# Epoch 6/50
# 9/9 - 0s - loss: 0.8531 - accuracy: 0.8479 - val_loss: 1.1859 - val_accuracy: 0.6830
# Epoch 7/50
# 9/9 - 0s - loss: 0.7078 - accuracy: 0.8897 - val_loss: 1.1133 - val_accuracy: 0.7098
# Epoch 8/50
# 9/9 - 0s - loss: 0.5879 - accuracy: 0.9275 - val_loss: 1.0588 - val_accuracy: 0.7366
# Epoch 9/50
# 9/9 - 0s - loss: 0.4926 - accuracy: 0.9480 - val_loss: 1.0074 - val_accuracy: 0.7321
# Epoch 10/50
# 9/9 - 0s - loss: 0.4143 - accuracy: 0.9645 - val_loss: 0.9684 - val_accuracy: 0.7411
# Epoch 11/50
# 9/9 - 0s - loss: 0.3510 - accuracy: 0.9716 - val_loss: 0.9461 - val_accuracy: 0.7545
# Epoch 12/50
# 9/9 - 0s - loss: 0.2981 - accuracy: 0.9811 - val_loss: 0.9263 - val_accuracy: 0.7455
# Epoch 13/50
# 9/9 - 0s - loss: 0.2545 - accuracy: 0.9874 - val_loss: 0.9079 - val_accuracy: 0.7455
# Epoch 14/50
# 9/9 - 0s - loss: 0.2190 - accuracy: 0.9913 - val_loss: 0.8933 - val_accuracy: 0.7545
# Epoch 15/50
# 9/9 - 0s - loss: 0.1896 - accuracy: 0.9937 - val_loss: 0.8809 - val_accuracy: 0.7634
# Epoch 16/50
# 9/9 - 0s - loss: 0.1651 - accuracy: 0.9961 - val_loss: 0.8725 - val_accuracy: 0.7589
# Epoch 17/50
# 9/9 - 0s - loss: 0.1448 - accuracy: 0.9984 - val_loss: 0.8681 - val_accuracy: 0.7589
# Epoch 18/50
# 9/9 - 0s - loss: 0.1276 - accuracy: 0.9992 - val_loss: 0.8622 - val_accuracy: 0.7589
# Epoch 19/50
# 9/9 - 0s - loss: 0.1135 - accuracy: 0.9992 - val_loss: 0.8504 - val_accuracy: 0.7500
# Epoch 20/50
# 9/9 - 0s - loss: 0.1021 - accuracy: 0.9992 - val_loss: 0.8474 - val_accuracy: 0.7500
# Epoch 21/50
# 9/9 - 0s - loss: 0.0915 - accuracy: 0.9992 - val_loss: 0.8459 - val_accuracy: 0.7500
# Epoch 22/50
# 9/9 - 0s - loss: 0.0828 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.7500
# Epoch 23/50
# 9/9 - 0s - loss: 0.0756 - accuracy: 1.0000 - val_loss: 0.8361 - val_accuracy: 0.7455
# Epoch 24/50
# 9/9 - 0s - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.8333 - val_accuracy: 0.7500
# Epoch 25/50
# 9/9 - 0s - loss: 0.0633 - accuracy: 1.0000 - val_loss: 0.8321 - val_accuracy: 0.7500
# Epoch 26/50
# 9/9 - 0s - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.8342 - val_accuracy: 0.7589
# Epoch 27/50
# 9/9 - 0s - loss: 0.0541 - accuracy: 1.0000 - val_loss: 0.8337 - val_accuracy: 0.7589
# Epoch 28/50
# 9/9 - 0s - loss: 0.0503 - accuracy: 1.0000 - val_loss: 0.8264 - val_accuracy: 0.7545
# Epoch 29/50
# 9/9 - 0s - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.8301 - val_accuracy: 0.7589
# Epoch 30/50
# 9/9 - 0s - loss: 0.0435 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7589
# Epoch 31/50
# 9/9 - 0s - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.8303 - val_accuracy: 0.7589
# Epoch 32/50
# 9/9 - 0s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.8276 - val_accuracy: 0.7589
# Epoch 33/50
# 9/9 - 0s - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.8286 - val_accuracy: 0.7589
# Epoch 34/50
# 9/9 - 0s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.8263 - val_accuracy: 0.7545
# Epoch 35/50
# 9/9 - 0s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7545
# Epoch 36/50
# 9/9 - 0s - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.8284 - val_accuracy: 0.7545
# Epoch 37/50
# 9/9 - 0s - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.8270 - val_accuracy: 0.7545
# Epoch 38/50
# 9/9 - 0s - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.8291 - val_accuracy: 0.7500
# Epoch 39/50
# 9/9 - 0s - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.8279 - val_accuracy: 0.7545
# Epoch 40/50
# 9/9 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.8289 - val_accuracy: 0.7634
# Epoch 41/50
# 9/9 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.8283 - val_accuracy: 0.7589
# Epoch 42/50
# 9/9 - 0s - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.8269 - val_accuracy: 0.7589
# Epoch 43/50
# 9/9 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.8280 - val_accuracy: 0.7589
# Epoch 44/50
# 9/9 - 0s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.7589
# Epoch 45/50
# 9/9 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.8285 - val_accuracy: 0.7589
# Epoch 46/50
# 9/9 - 0s - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.8312 - val_accuracy: 0.7589
# Epoch 47/50
# 9/9 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.8298 - val_accuracy: 0.7545
# Epoch 48/50
# 9/9 - 0s - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.8290 - val_accuracy: 0.7545
# Epoch 49/50
# 9/9 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.8307 - val_accuracy: 0.7589
# Epoch 50/50
# 9/9 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.8327 - val_accuracy: 0.7545

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 12/12 [==============================] - 0s 997us/step - loss: 0.8448 - accuracy: 0.7567

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
