# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 70 # número mínimo de fotos por personaje para filtrar la base
resize=0.7 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1288
# Classes: 7
# Dimentions: (87, 65)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1030, 5655)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (258, 5655)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1030, 7)
# (258, 7)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               3223920
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 672
# =================================================================
# Total params: 3,278,837
# Trainable params: 3,278,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.309, max:    0.558, cur:    0.541)
# 	validation       	 (min:    0.461, max:    0.601, cur:    0.585)
# Loss
# 	training         	 (min:    1.290, max:    1.973, cur:    1.294)
# 	validation       	 (min:    1.214, max:    1.627, cur:    1.214)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 1.2137 - accuracy: 0.5853

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128],[350,35]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 2

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002131BD749D8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002131BCDDA68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'sgd', 'hidden_layers': [512, 128], 'epochs': 50, 'batch_size': 184}
# 0.4436893203883495

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(128, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               2895872
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 2,962,439
# Trainable params: 2,962,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 184 # Tamaño de la ventana
epoc = 50 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.348, max:    0.798, cur:    0.768)
# 	validation       	 (min:    0.461, max:    0.787, cur:    0.783)
# Loss
# 	training         	 (min:    0.702, max:    1.837, cur:    0.732)
# 	validation       	 (min:    0.728, max:    1.614, cur:    0.771)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7714 - accuracy: 0.7829

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1030, 5655)
# (1030, 200)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(512, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(128, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               102912
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 169,479
# Trainable params: 169,479
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=epoc, batch_size=size, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/50
# 5/5 - 1s - loss: 1.8238 - accuracy: 0.3234 - val_loss: 1.4672 - val_accuracy: 0.4645
# Epoch 2/50
# 5/5 - 0s - loss: 1.2920 - accuracy: 0.5326 - val_loss: 1.2391 - val_accuracy: 0.6000
# Epoch 3/50
# 5/5 - 0s - loss: 0.9789 - accuracy: 0.7360 - val_loss: 1.1067 - val_accuracy: 0.6645
# Epoch 4/50
# 5/5 - 0s - loss: 0.7443 - accuracy: 0.8354 - val_loss: 0.9303 - val_accuracy: 0.6968
# Epoch 5/50
# 5/5 - 0s - loss: 0.5642 - accuracy: 0.8789 - val_loss: 0.7989 - val_accuracy: 0.7484
# Epoch 6/50
# 5/5 - 0s - loss: 0.4252 - accuracy: 0.9314 - val_loss: 0.7383 - val_accuracy: 0.7613
# Epoch 7/50
# 5/5 - 0s - loss: 0.3255 - accuracy: 0.9737 - val_loss: 0.6833 - val_accuracy: 0.7806
# Epoch 8/50
# 5/5 - 0s - loss: 0.2495 - accuracy: 0.9874 - val_loss: 0.6389 - val_accuracy: 0.7806
# Epoch 9/50
# 5/5 - 0s - loss: 0.1932 - accuracy: 0.9943 - val_loss: 0.6153 - val_accuracy: 0.7871
# Epoch 10/50
# 5/5 - 0s - loss: 0.1508 - accuracy: 0.9954 - val_loss: 0.5957 - val_accuracy: 0.8000
# Epoch 11/50
# 5/5 - 0s - loss: 0.1218 - accuracy: 0.9966 - val_loss: 0.5779 - val_accuracy: 0.7935
# Epoch 12/50
# 5/5 - 0s - loss: 0.0987 - accuracy: 1.0000 - val_loss: 0.5683 - val_accuracy: 0.8065
# Epoch 13/50
# 5/5 - 0s - loss: 0.0824 - accuracy: 1.0000 - val_loss: 0.5617 - val_accuracy: 0.8065
# Epoch 14/50
# 5/5 - 0s - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.5558 - val_accuracy: 0.8194
# Epoch 15/50
# 5/5 - 0s - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.5509 - val_accuracy: 0.8129
# Epoch 16/50
# 5/5 - 0s - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.5469 - val_accuracy: 0.8129
# Epoch 17/50
# 5/5 - 0s - loss: 0.0460 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.8129
# Epoch 18/50
# 5/5 - 0s - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.5447 - val_accuracy: 0.8258
# Epoch 19/50
# 5/5 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 0.5450 - val_accuracy: 0.8194
# Epoch 20/50
# 5/5 - 0s - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.5443 - val_accuracy: 0.8258
# Epoch 21/50
# 5/5 - 0s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.5441 - val_accuracy: 0.8258
# Epoch 22/50
# 5/5 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.5429 - val_accuracy: 0.8258
# Epoch 23/50
# 5/5 - 0s - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.5425 - val_accuracy: 0.8323
# Epoch 24/50
# 5/5 - 0s - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.5432 - val_accuracy: 0.8323
# Epoch 25/50
# 5/5 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.5440 - val_accuracy: 0.8387
# Epoch 26/50
# 5/5 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.5445 - val_accuracy: 0.8387
# Epoch 27/50
# 5/5 - 0s - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.8387
# Epoch 28/50
# 5/5 - 0s - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 0.8387
# Epoch 29/50
# 5/5 - 0s - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.5484 - val_accuracy: 0.8387
# Epoch 30/50
# 5/5 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.5486 - val_accuracy: 0.8323
# Epoch 31/50
# 5/5 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 0.5486 - val_accuracy: 0.8323
# Epoch 32/50
# 5/5 - 0s - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.5497 - val_accuracy: 0.8323
# Epoch 33/50
# 5/5 - 0s - loss: 0.0134 - accuracy: 1.0000 - val_loss: 0.5512 - val_accuracy: 0.8323
# Epoch 34/50
# 5/5 - 0s - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 0.8258
# Epoch 35/50
# 5/5 - 0s - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.5529 - val_accuracy: 0.8258
# Epoch 36/50
# 5/5 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 0.5538 - val_accuracy: 0.8258
# Epoch 37/50
# 5/5 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.5543 - val_accuracy: 0.8258
# Epoch 38/50
# 5/5 - 0s - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.5554 - val_accuracy: 0.8258
# Epoch 39/50
# 5/5 - 0s - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5556 - val_accuracy: 0.8258
# Epoch 40/50
# 5/5 - 0s - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.5568 - val_accuracy: 0.8258
# Epoch 41/50
# 5/5 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.5574 - val_accuracy: 0.8258
# Epoch 42/50
# 5/5 - 0s - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.5586 - val_accuracy: 0.8258
# Epoch 43/50
# 5/5 - 0s - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.8258
# Epoch 44/50
# 5/5 - 0s - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.5604 - val_accuracy: 0.8258
# Epoch 45/50
# 5/5 - 0s - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.8258
# Epoch 46/50
# 5/5 - 0s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.5622 - val_accuracy: 0.8258
# Epoch 47/50
# 5/5 - 0s - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.5630 - val_accuracy: 0.8258
# Epoch 48/50
# 5/5 - 0s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.5639 - val_accuracy: 0.8258
# Epoch 49/50
# 5/5 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.5651 - val_accuracy: 0.8258
# Epoch 50/50
# 5/5 - 0s - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.8258

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 997us/step - loss: 0.4722 - accuracy: 0.8682

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
