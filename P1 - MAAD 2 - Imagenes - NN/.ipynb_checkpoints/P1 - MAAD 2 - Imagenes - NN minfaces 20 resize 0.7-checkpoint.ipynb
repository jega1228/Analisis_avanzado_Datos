# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librarías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 20 # número mínimo de fotos por personaje para filtrar la base
resize=0.7 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 3023
# Classes: 62
# Dimentions: (87, 65)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (2418, 5655)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (605, 5655)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (2418, 62)
# (605, 62)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(512, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(128, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               2895872
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                7998
# =================================================================
# Total params: 2,969,534
# Trainable params: 2,969,534
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 60 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.176, max:    0.179, cur:    0.179)
# 	validation       	 (min:    0.160, max:    0.160, cur:    0.160)
# Loss
# 	training         	 (min:    3.674, max:    3.735, cur:    3.677)
# 	validation       	 (min:    3.709, max:    3.728, cur:    3.719)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 19/19 [==============================] - 0s 4ms/step - loss: 3.7191 - accuracy: 0.1603

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 128],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128], [350,150]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 43

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000246817E1708> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000246F6926C18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'rmsprop', 'hidden_layers': [580, 100], 'epochs': 50, 'batch_size': 48}
# 0.18238743527313878

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(580, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(100, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               3280480
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                6262
# =================================================================
# Total params: 3,344,842
# Trainable params: 3,344,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 50 # Tamaño de la ventana
epoc = 48 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.175, max:    0.179, cur:    0.179)
# 	validation       	 (min:    0.160, max:    0.160, cur:    0.160)
# Loss
# 	training         	 (min:    3.671, max:    3.798, cur:    3.674)
# 	validation       	 (min:    3.709, max:    3.781, cur:    3.714)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 19/19 [==============================] - 0s 4ms/step - loss: 3.7141 - accuracy: 0.1603

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1493)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (2418, 5655)
# (2418, 200)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(580, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(100, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 580)               116580
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               58100
# _________________________________________________________________
# dense_2 (Dense)              (None, 62)                6262
# =================================================================
# Total params: 180,942
# Trainable params: 180,942
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=50, batch_size=48, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/50
# 43/43 - 1s - loss: 3.5802 - accuracy: 0.1922 - val_loss: 3.2101 - val_accuracy: 0.2397
# Epoch 2/50
# 43/43 - 0s - loss: 2.8034 - accuracy: 0.3275 - val_loss: 2.8017 - val_accuracy: 0.3196
# Epoch 3/50
# 43/43 - 0s - loss: 2.2408 - accuracy: 0.4710 - val_loss: 2.4858 - val_accuracy: 0.4353
# Epoch 4/50
# 43/43 - 0s - loss: 1.7713 - accuracy: 0.6292 - val_loss: 2.2625 - val_accuracy: 0.5096
# Epoch 5/50
# 43/43 - 0s - loss: 1.4058 - accuracy: 0.7591 - val_loss: 2.1051 - val_accuracy: 0.5510
# Epoch 6/50
# 43/43 - 0s - loss: 1.1012 - accuracy: 0.8487 - val_loss: 1.9708 - val_accuracy: 0.5868
# Epoch 7/50
# 43/43 - 0s - loss: 0.8650 - accuracy: 0.9124 - val_loss: 1.8743 - val_accuracy: 0.5978
# Epoch 8/50
# 43/43 - 0s - loss: 0.6712 - accuracy: 0.9572 - val_loss: 1.8053 - val_accuracy: 0.6088
# Epoch 9/50
# 43/43 - 0s - loss: 0.5199 - accuracy: 0.9844 - val_loss: 1.7493 - val_accuracy: 0.6281
# Epoch 10/50
# 43/43 - 0s - loss: 0.4012 - accuracy: 0.9917 - val_loss: 1.7107 - val_accuracy: 0.6309
# Epoch 11/50
# 43/43 - 0s - loss: 0.3131 - accuracy: 0.9966 - val_loss: 1.6735 - val_accuracy: 0.6253
# Epoch 12/50
# 43/43 - 0s - loss: 0.2468 - accuracy: 0.9990 - val_loss: 1.6522 - val_accuracy: 0.6336
# Epoch 13/50
# 43/43 - 0s - loss: 0.1992 - accuracy: 0.9990 - val_loss: 1.6268 - val_accuracy: 0.6309
# Epoch 14/50
# 43/43 - 0s - loss: 0.1643 - accuracy: 0.9995 - val_loss: 1.6145 - val_accuracy: 0.6309
# Epoch 15/50
# 43/43 - 0s - loss: 0.1366 - accuracy: 0.9995 - val_loss: 1.5958 - val_accuracy: 0.6364
# Epoch 16/50
# 43/43 - 0s - loss: 0.1162 - accuracy: 1.0000 - val_loss: 1.5881 - val_accuracy: 0.6281
# Epoch 17/50
# 43/43 - 0s - loss: 0.0996 - accuracy: 1.0000 - val_loss: 1.5774 - val_accuracy: 0.6364
# Epoch 18/50
# 43/43 - 0s - loss: 0.0865 - accuracy: 1.0000 - val_loss: 1.5704 - val_accuracy: 0.6336
# Epoch 19/50
# 43/43 - 0s - loss: 0.0756 - accuracy: 1.0000 - val_loss: 1.5629 - val_accuracy: 0.6364
# Epoch 20/50
# 43/43 - 0s - loss: 0.0669 - accuracy: 1.0000 - val_loss: 1.5586 - val_accuracy: 0.6364
# Epoch 21/50
# 43/43 - 0s - loss: 0.0596 - accuracy: 1.0000 - val_loss: 1.5539 - val_accuracy: 0.6446
# Epoch 22/50
# 43/43 - 0s - loss: 0.0534 - accuracy: 1.0000 - val_loss: 1.5490 - val_accuracy: 0.6501
# Epoch 23/50
# 43/43 - 0s - loss: 0.0482 - accuracy: 1.0000 - val_loss: 1.5462 - val_accuracy: 0.6446
# Epoch 24/50
# 43/43 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.5430 - val_accuracy: 0.6474
# Epoch 25/50
# 43/43 - 0s - loss: 0.0398 - accuracy: 1.0000 - val_loss: 1.5398 - val_accuracy: 0.6474
# Epoch 26/50
# 43/43 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.5399 - val_accuracy: 0.6501
# Epoch 27/50
# 43/43 - 0s - loss: 0.0336 - accuracy: 1.0000 - val_loss: 1.5393 - val_accuracy: 0.6501
# Epoch 28/50
# 43/43 - 0s - loss: 0.0311 - accuracy: 1.0000 - val_loss: 1.5342 - val_accuracy: 0.6501
# Epoch 29/50
# 43/43 - 0s - loss: 0.0288 - accuracy: 1.0000 - val_loss: 1.5350 - val_accuracy: 0.6529
# Epoch 30/50
# 43/43 - 0s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 1.5349 - val_accuracy: 0.6474
# Epoch 31/50
# 43/43 - 0s - loss: 0.0250 - accuracy: 1.0000 - val_loss: 1.5315 - val_accuracy: 0.6584
# Epoch 32/50
# 43/43 - 0s - loss: 0.0233 - accuracy: 1.0000 - val_loss: 1.5290 - val_accuracy: 0.6584
# Epoch 33/50
# 43/43 - 0s - loss: 0.0219 - accuracy: 1.0000 - val_loss: 1.5306 - val_accuracy: 0.6556
# Epoch 34/50
# 43/43 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 1.5279 - val_accuracy: 0.6584
# Epoch 35/50
# 43/43 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 1.5274 - val_accuracy: 0.6584
# Epoch 36/50
# 43/43 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 1.5269 - val_accuracy: 0.6584
# Epoch 37/50
# 43/43 - 0s - loss: 0.0172 - accuracy: 1.0000 - val_loss: 1.5264 - val_accuracy: 0.6584
# Epoch 38/50
# 43/43 - 0s - loss: 0.0162 - accuracy: 1.0000 - val_loss: 1.5256 - val_accuracy: 0.6584
# Epoch 39/50
# 43/43 - 0s - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.5272 - val_accuracy: 0.6584
# Epoch 40/50
# 43/43 - 0s - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.5261 - val_accuracy: 0.6584
# Epoch 41/50
# 43/43 - 0s - loss: 0.0138 - accuracy: 1.0000 - val_loss: 1.5281 - val_accuracy: 0.6584
# Epoch 42/50
# 43/43 - 0s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.5269 - val_accuracy: 0.6584
# Epoch 43/50
# 43/43 - 0s - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.5298 - val_accuracy: 0.6584
# Epoch 44/50
# 43/43 - 0s - loss: 0.0118 - accuracy: 1.0000 - val_loss: 1.5255 - val_accuracy: 0.6584
# Epoch 45/50
# 43/43 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 1.5278 - val_accuracy: 0.6584
# Epoch 46/50
# 43/43 - 0s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 1.5268 - val_accuracy: 0.6584
# Epoch 47/50
# 43/43 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.5259 - val_accuracy: 0.6612
# Epoch 48/50
# 43/43 - 0s - loss: 0.0098 - accuracy: 1.0000 - val_loss: 1.5290 - val_accuracy: 0.6584
# Epoch 49/50
# 43/43 - 0s - loss: 0.0094 - accuracy: 1.0000 - val_loss: 1.5281 - val_accuracy: 0.6584
# Epoch 50/50
# 43/43 - 0s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.5265 - val_accuracy: 0.6612

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 19/19 [==============================] - 0s 1ms/step - loss: 1.6377 - accuracy: 0.6380

# %% [markdown]
# ### BIBLIOGRAFÍA
#
# https://www.kaggle.com/joparga3/2-tuning-parameters-for-logistic-regression
#
# https://www.projectpro.io/recipes/optimize-hyper-parameters-of-logistic-regression-model-using-grid-search-in-python
#
# https://github.com/harshitrai17152/Labeled-Faces-in-the-Wild.git
