# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# # Red Neuronal Multicapa - NN

# %% [markdown]
# Elaborado por:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librerías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 60 # número mínimo de fotos por personaje para filtrar la base
resize=0.7 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1348
# Classes: 8
# Dimentions: (87, 65)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1078, 5655)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (270, 5655)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1078, 8)
# (270, 8)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               3223920
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 768
# =================================================================
# Total params: 3,278,933
# Trainable params: 3,278,933
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.353, max:    0.558, cur:    0.558)
# 	validation       	 (min:    0.363, max:    0.548, cur:    0.522)
# Loss
# 	training         	 (min:    1.402, max:    2.049, cur:    1.404)
# 	validation       	 (min:    1.475, max:    1.890, cur:    1.475)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 4ms/step - loss: 1.4750 - accuracy: 0.5222

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128],[350,15]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 1

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002361BD42E58> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000023618332CA8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [350, 15], 'epochs': 50, 'batch_size': 50}
# 0.42203184492904117

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(350, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(15, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 350)               1979600
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                5265
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 128
# =================================================================
# Total params: 1,984,993
# Trainable params: 1,984,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 50 # Tamaño de la ventana
epoc = 50 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.391, max:    0.401, cur:    0.401)
# 	validation       	 (min:    0.363, max:    0.363, cur:    0.363)
# Loss
# 	training         	 (min:    1.782, max:    1.856, cur:    1.789)
# 	validation       	 (min:    1.812, max:    1.875, cur:    1.813)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 1.8128 - accuracy: 0.3630

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1078, 5655)
# (1078, 200)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(350, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(15, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 350)               70350
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                5265
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 128
# =================================================================
# Total params: 75,743
# Trainable params: 75,743
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=50, batch_size=50, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/50
# 19/19 - 1s - loss: 2.1150 - accuracy: 0.1627 - val_loss: 1.8356 - val_accuracy: 0.3765
# Epoch 2/50
# 19/19 - 0s - loss: 1.6727 - accuracy: 0.5437 - val_loss: 1.6249 - val_accuracy: 0.5494
# Epoch 3/50
# 19/19 - 0s - loss: 1.4653 - accuracy: 0.6616 - val_loss: 1.5152 - val_accuracy: 0.6111
# Epoch 4/50
# 19/19 - 0s - loss: 1.3015 - accuracy: 0.7740 - val_loss: 1.4100 - val_accuracy: 0.6420
# Epoch 5/50
# 19/19 - 0s - loss: 1.1467 - accuracy: 0.8417 - val_loss: 1.3079 - val_accuracy: 0.6914
# Epoch 6/50
# 19/19 - 0s - loss: 1.0116 - accuracy: 0.8952 - val_loss: 1.2249 - val_accuracy: 0.6975
# Epoch 7/50
# 19/19 - 0s - loss: 0.8873 - accuracy: 0.9247 - val_loss: 1.1592 - val_accuracy: 0.6914
# Epoch 8/50
# 19/19 - 0s - loss: 0.7886 - accuracy: 0.9541 - val_loss: 1.0892 - val_accuracy: 0.7037
# Epoch 9/50
# 19/19 - 0s - loss: 0.7054 - accuracy: 0.9640 - val_loss: 1.0458 - val_accuracy: 0.7160
# Epoch 10/50
# 19/19 - 0s - loss: 0.6336 - accuracy: 0.9727 - val_loss: 1.0026 - val_accuracy: 0.7346
# Epoch 11/50
# 19/19 - 0s - loss: 0.5747 - accuracy: 0.9793 - val_loss: 0.9660 - val_accuracy: 0.7222
# Epoch 12/50
# 19/19 - 0s - loss: 0.5242 - accuracy: 0.9836 - val_loss: 0.9349 - val_accuracy: 0.7593
# Epoch 13/50
# 19/19 - 0s - loss: 0.4804 - accuracy: 0.9836 - val_loss: 0.9106 - val_accuracy: 0.7654
# Epoch 14/50
# 19/19 - 0s - loss: 0.4423 - accuracy: 0.9836 - val_loss: 0.8835 - val_accuracy: 0.7593
# Epoch 15/50
# 19/19 - 0s - loss: 0.4090 - accuracy: 0.9869 - val_loss: 0.8617 - val_accuracy: 0.7654
# Epoch 16/50
# 19/19 - 0s - loss: 0.3789 - accuracy: 0.9924 - val_loss: 0.8420 - val_accuracy: 0.7654
# Epoch 17/50
# 19/19 - 0s - loss: 0.3515 - accuracy: 0.9934 - val_loss: 0.8280 - val_accuracy: 0.7654
# Epoch 18/50
# 19/19 - 0s - loss: 0.3273 - accuracy: 0.9934 - val_loss: 0.8113 - val_accuracy: 0.7654
# Epoch 19/50
# 19/19 - 0s - loss: 0.3060 - accuracy: 0.9945 - val_loss: 0.7960 - val_accuracy: 0.7654
# Epoch 20/50
# 19/19 - 0s - loss: 0.2869 - accuracy: 0.9945 - val_loss: 0.7866 - val_accuracy: 0.7654
# Epoch 21/50
# 19/19 - 0s - loss: 0.2696 - accuracy: 0.9945 - val_loss: 0.7744 - val_accuracy: 0.7654
# Epoch 22/50
# 19/19 - 0s - loss: 0.2543 - accuracy: 0.9945 - val_loss: 0.7635 - val_accuracy: 0.7716
# Epoch 23/50
# 19/19 - 0s - loss: 0.2405 - accuracy: 0.9945 - val_loss: 0.7512 - val_accuracy: 0.7840
# Epoch 24/50
# 19/19 - 0s - loss: 0.2269 - accuracy: 0.9956 - val_loss: 0.7439 - val_accuracy: 0.7778
# Epoch 25/50
# 19/19 - 0s - loss: 0.2118 - accuracy: 0.9956 - val_loss: 0.7357 - val_accuracy: 0.7778
# Epoch 26/50
# 19/19 - 0s - loss: 0.1972 - accuracy: 0.9967 - val_loss: 0.7290 - val_accuracy: 0.7778
# Epoch 27/50
# 19/19 - 0s - loss: 0.1854 - accuracy: 0.9967 - val_loss: 0.7215 - val_accuracy: 0.7778
# Epoch 28/50
# 19/19 - 0s - loss: 0.1747 - accuracy: 0.9978 - val_loss: 0.7163 - val_accuracy: 0.7778
# Epoch 29/50
# 19/19 - 0s - loss: 0.1649 - accuracy: 0.9978 - val_loss: 0.7049 - val_accuracy: 0.7963
# Epoch 30/50
# 19/19 - 0s - loss: 0.1558 - accuracy: 0.9967 - val_loss: 0.6965 - val_accuracy: 0.7901
# Epoch 31/50
# 19/19 - 0s - loss: 0.1474 - accuracy: 0.9967 - val_loss: 0.6906 - val_accuracy: 0.7963
# Epoch 32/50
# 19/19 - 0s - loss: 0.1393 - accuracy: 0.9967 - val_loss: 0.6827 - val_accuracy: 0.8148
# Epoch 33/50
# 19/19 - 0s - loss: 0.1316 - accuracy: 0.9978 - val_loss: 0.6806 - val_accuracy: 0.8148
# Epoch 34/50
# 19/19 - 0s - loss: 0.1246 - accuracy: 0.9978 - val_loss: 0.6752 - val_accuracy: 0.8210
# Epoch 35/50
# 19/19 - 0s - loss: 0.1184 - accuracy: 0.9978 - val_loss: 0.6668 - val_accuracy: 0.8210
# Epoch 36/50
# 19/19 - 0s - loss: 0.1124 - accuracy: 0.9978 - val_loss: 0.6635 - val_accuracy: 0.8272
# Epoch 37/50
# 19/19 - 0s - loss: 0.1074 - accuracy: 0.9978 - val_loss: 0.6593 - val_accuracy: 0.8210
# Epoch 38/50
# 19/19 - 0s - loss: 0.1028 - accuracy: 0.9978 - val_loss: 0.6553 - val_accuracy: 0.8210
# Epoch 39/50
# 19/19 - 0s - loss: 0.0986 - accuracy: 0.9978 - val_loss: 0.6544 - val_accuracy: 0.8210
# Epoch 40/50
# 19/19 - 0s - loss: 0.0947 - accuracy: 0.9978 - val_loss: 0.6570 - val_accuracy: 0.8210
# Epoch 41/50
# 19/19 - 0s - loss: 0.0911 - accuracy: 0.9978 - val_loss: 0.6555 - val_accuracy: 0.8210
# Epoch 42/50
# 19/19 - 0s - loss: 0.0878 - accuracy: 0.9978 - val_loss: 0.6543 - val_accuracy: 0.8148
# Epoch 43/50
# 19/19 - 0s - loss: 0.0848 - accuracy: 0.9978 - val_loss: 0.6505 - val_accuracy: 0.8210
# Epoch 44/50
# 19/19 - 0s - loss: 0.0818 - accuracy: 0.9978 - val_loss: 0.6490 - val_accuracy: 0.8210
# Epoch 45/50
# 19/19 - 0s - loss: 0.0786 - accuracy: 0.9978 - val_loss: 0.6515 - val_accuracy: 0.8210
# Epoch 46/50
# 19/19 - 0s - loss: 0.0759 - accuracy: 0.9978 - val_loss: 0.6505 - val_accuracy: 0.8210
# Epoch 47/50
# 19/19 - 0s - loss: 0.0731 - accuracy: 0.9978 - val_loss: 0.6488 - val_accuracy: 0.8210
# Epoch 48/50
# 19/19 - 0s - loss: 0.0708 - accuracy: 0.9978 - val_loss: 0.6473 - val_accuracy: 0.8210
# Epoch 49/50
# 19/19 - 0s - loss: 0.0687 - accuracy: 0.9978 - val_loss: 0.6451 - val_accuracy: 0.8210
# Epoch 50/50
# 19/19 - 0s - loss: 0.0666 - accuracy: 0.9978 - val_loss: 0.6420 - val_accuracy: 0.8210

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6039 - accuracy: 0.8333
