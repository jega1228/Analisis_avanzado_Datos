# %% [markdown]
# # P1 - Identificando personas desde una imagen de su cara

# %% [markdown]
# # Red Neuronal Multicapa - NN

# %% [markdown]
# Elaborado por:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
# Librerías
from sklearn.datasets import fetch_lfw_people
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

from keras import models
from keras import layers
from keras import preprocessing
from keras import backend as K
from livelossplot import PlotLossesKeras

import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import scikitplot as skplt

from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# DataSet : “Labeled Faces in the Wild”
min_faces_per_person = 60 # número mínimo de fotos por personaje para filtrar la base
resize=0.5 # Número de define la calidad de las imágenes

# con 10 mín  fotos se generan 158 categorías
# con 40 mín  fotos se generan 19 categorías
# con 50 mín  fotos se generan 12 categorías

# %%
# Some definitions

data = fetch_lfw_people(min_faces_per_person=min_faces_per_person, resize=resize)

l=list(data.keys())
X=data[l[0]]
y=data[l[2]]
target_names=data[l[3]]

_,W,H=data[l[1]].shape
features=X.shape[1]
m=X.shape[0]
classes=data[l[3]].shape[0]

print("Resumen Imágenes a procesar")
print("Samples:",m)
print("Classes:",classes)
print("Dimentions:",(W,H))
# Out:
# Resumen Imágenes a procesar
# Samples: 1348
# Classes: 8
# Dimentions: (62, 47)

# %%
for i in range(6):
  img=X[i,:]
  img=img.reshape(W,H)
  plt.subplot(2,3,i+1)
  plt.title(target_names[y[i]])
  plt.imshow(img,cmap='gray')
  plt.axis('off')
plt.show()

# %%
# split into a training and testing set
X_train_image, X_test_image, y_train_labels, y_test_labels = train_test_split(
    X, y, test_size=0.20, random_state=42)

# %%
#shape train
print(X_train_image.shape)
n_train=X_train_image.shape[0]
# Out:
# (1078, 2914)

# %%
#shape test
print(X_test_image.shape)
n_test=X_test_image.shape[0]
# Out:
# (270, 2914)

# %%
# Transformación 
X_train_image = X_train_image.reshape((n_train, W * H))
X_train_image = X_train_image.astype('float32') / 255
X_test_image = X_test_image.reshape((n_test, W * H))
X_test_image = X_test_image.astype('float32') / 255

# %%
# Categorización 
y_train_labels = to_categorical(y_train_labels)
y_test_labels = to_categorical(y_test_labels)

# %%
# Validación dimensiones variable respuesta en dataset de entrenamiento y pruebas
print(y_train_labels.shape)
print(y_test_labels.shape)
# Out:
# (1078, 8)
# (270, 8)

# %% [markdown]
# ### MODELO 1 - NN

# %%
# model compilation
K.clear_session()
model_1 = models.Sequential()
model_1.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
model_1.add(layers.Dense(95, activation='sigmoid'))
model_1.add(layers.Dense(classes, activation='softmax'))
model_1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 570)               1661550
# _________________________________________________________________
# dense_1 (Dense)              (None, 95)                54245
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 768
# =================================================================
# Total params: 1,716,563
# Trainable params: 1,716,563
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = int(m/classes) # Tamaño de la ventana
epoc = 50 # Número de épocas

#model_1.fit(X_train_image, y_train_labels, epochs=epoc, batch_size=size)
model_1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.358, max:    0.878, cur:    0.878)
# 	validation       	 (min:    0.363, max:    0.807, cur:    0.763)
# Loss
# 	training         	 (min:    0.451, max:    1.953, cur:    0.451)
# 	validation       	 (min:    0.668, max:    1.853, cur:    0.761)

# %%
# model's performance on test set
test_loss, test_acc = model_1.evaluate(X_test_image, y_test_labels)
# Out:
# 9/9 [==============================] - 0s 3ms/step - loss: 0.7612 - accuracy: 0.7630

# %% [markdown]
# ### MODELO 2 - NN CON TUNNING

# %%
K.clear_session()
def build_keras_base(hidden_layers = [512, 19],  
                     optimizer='adam'):
    model_opt = models.Sequential()
    model_opt.add(layers.Dense(570, activation='relu', input_shape=(W * H,)))
    model_opt.add(layers.Dense(95, activation='sigmoid'))
    model_opt.add(layers.Dense(classes, activation='softmax'))
    model_opt.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
    return model_opt

# %%
model_keras = KerasClassifier(
    build_fn = build_keras_base, verbose=0
   
)

# %%
hidden_layers_opt=[[580,100], [256, 64],[512,128],[350,15]] 
batch_size_opt= [size, 50,150] 
epochs_opt= [50,60]
optimizer= ['sgd', 'rmsprop',"adam"]

parameters_opt = {'hidden_layers':hidden_layers_opt,
                  'optimizer': optimizer,
                  'batch_size': batch_size_opt, 
                  'epochs': epochs_opt , 
                  
                 }

# %%
grid_search =  RandomizedSearchCV(model_keras,
                                  param_distributions = parameters_opt, 
                                  scoring = 'accuracy', 
                                  n_iter = 3, 
                                  cv = 10)

# %%
rounded_labels=np.argmax(y_train_labels, axis=1)
rounded_labels[1]
# Out:
# 1

# %%
grid_result = grid_search.fit(X_train_image, rounded_labels, verbose=0)

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_
print(best_parameters)
print(best_accuracy)
# Out:
# {'optimizer': 'adam', 'hidden_layers': [256, 64], 'epochs': 60, 'batch_size': 168}
# 0.769055036344756

# %%
# model compilation
K.clear_session()
model_opt1 = models.Sequential()
model_opt1.add(layers.Dense(256, activation='relu', input_shape=(W * H,)))
model_opt1.add(layers.Dense(64, activation='sigmoid'))
model_opt1.add(layers.Dense(classes, activation='softmax'))
model_opt1.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_opt1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               746240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 763,208
# Trainable params: 763,208
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
size = 168 # Tamaño de la ventana
epoc = 60 # Número de épocas

model_opt1.fit(X_train_image, y_train_labels, validation_data=(X_test_image, y_test_labels), \
            epochs=epoc, batch_size=size, verbose=1, callbacks=[PlotLossesKeras()])
# Out:
# accuracy
# 	training         	 (min:    0.347, max:    0.884, cur:    0.871)
# 	validation       	 (min:    0.363, max:    0.815, cur:    0.778)
# Loss
# 	training         	 (min:    0.436, max:    1.875, cur:    0.451)
# 	validation       	 (min:    0.692, max:    1.803, cur:    0.732)

# %%
# model's performance on test set
test_loss, test_acc = model_opt1.evaluate(X_test_image, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.7318 - accuracy: 0.7778

# %% [markdown]
# ### MODELO 3 - PCA

# %%
#Estandarización antes de aplicar PCA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train_image)
X_sc_train = scaler.transform(X_train_image)
X_sc_test = scaler.transform(X_test_image)

# %%
#Análisis de Varianza acumulada
pca = PCA(n_components=1000)
pca.fit(X_train_image)

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
#Elección de componentes óptimos, se probaron 50, 100, 150 y 200
NCOMPONENTS = 200

pca = PCA(n_components=NCOMPONENTS)
X_pca_train = pca.fit_transform(X_sc_train)
X_pca_test = pca.transform(X_sc_test)
pca_std = np.std(X_pca_train)

print(X_sc_train.shape)
print(X_pca_train.shape)
# Out:
# (1078, 2914)
# (1078, 200)

# %%
#Se invierte el PCA con el fin de reconstruir las imágenes a partir de los 200 componentes seleccionados
inv_pca = pca.inverse_transform(X_pca_train)
inv_sc = scaler.inverse_transform(inv_pca)

# %%
def side_by_side(indexes):
    org = X_train_image[indexes].reshape(W,H)
    rec = inv_sc[indexes].reshape(W,H)
    pair = np.concatenate((org, rec), axis=1)
    plt.figure(figsize=(4,2))
    plt.imshow(pair)
    plt.show()
    
for index in range(0,10):
    side_by_side(index)

# %%
#Aplicación de la red neuronal con un input de 200 componentes
# model compilation
K.clear_session()
model_pca = models.Sequential()
model_pca.add(layers.Dense(256, activation='relu', input_dim=NCOMPONENTS))
model_pca.add(layers.Dense(64, activation='sigmoid'))
model_pca.add(layers.Dense(classes, activation='softmax'))
model_pca.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model_pca.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               51456
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# =================================================================
# Total params: 68,424
# Trainable params: 68,424
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_pca.fit(X_pca_train, y_train_labels, epochs=60, batch_size=168, validation_split=0.15, verbose=2)
# Out:
# Epoch 1/60
# 6/6 - 1s - loss: 2.3370 - accuracy: 0.1397 - val_loss: 1.8321 - val_accuracy: 0.2778
# Epoch 2/60
# 6/6 - 0s - loss: 1.6391 - accuracy: 0.4509 - val_loss: 1.5966 - val_accuracy: 0.4321
# Epoch 3/60
# 6/6 - 0s - loss: 1.4714 - accuracy: 0.4683 - val_loss: 1.5045 - val_accuracy: 0.4568
# Epoch 4/60
# 6/6 - 0s - loss: 1.3028 - accuracy: 0.5175 - val_loss: 1.3739 - val_accuracy: 0.5000
# Epoch 5/60
# 6/6 - 0s - loss: 1.1374 - accuracy: 0.6354 - val_loss: 1.2731 - val_accuracy: 0.5679
# Epoch 6/60
# 6/6 - 0s - loss: 0.9996 - accuracy: 0.7467 - val_loss: 1.1920 - val_accuracy: 0.6358
# Epoch 7/60
# 6/6 - 0s - loss: 0.8758 - accuracy: 0.8013 - val_loss: 1.1103 - val_accuracy: 0.6481
# Epoch 8/60
# 6/6 - 0s - loss: 0.7637 - accuracy: 0.8319 - val_loss: 1.0357 - val_accuracy: 0.6790
# Epoch 9/60
# 6/6 - 0s - loss: 0.6633 - accuracy: 0.8952 - val_loss: 0.9613 - val_accuracy: 0.7099
# Epoch 10/60
# 6/6 - 0s - loss: 0.5773 - accuracy: 0.9279 - val_loss: 0.9009 - val_accuracy: 0.7407
# Epoch 11/60
# 6/6 - 0s - loss: 0.5022 - accuracy: 0.9443 - val_loss: 0.8501 - val_accuracy: 0.7531
# Epoch 12/60
# 6/6 - 0s - loss: 0.4356 - accuracy: 0.9563 - val_loss: 0.8107 - val_accuracy: 0.7654
# Epoch 13/60
# 6/6 - 0s - loss: 0.3779 - accuracy: 0.9672 - val_loss: 0.7722 - val_accuracy: 0.7840
# Epoch 14/60
# 6/6 - 0s - loss: 0.3288 - accuracy: 0.9793 - val_loss: 0.7413 - val_accuracy: 0.7840
# Epoch 15/60
# 6/6 - 0s - loss: 0.2865 - accuracy: 0.9858 - val_loss: 0.7153 - val_accuracy: 0.8025
# Epoch 16/60
# 6/6 - 0s - loss: 0.2514 - accuracy: 0.9880 - val_loss: 0.6888 - val_accuracy: 0.8025
# Epoch 17/60
# 6/6 - 0s - loss: 0.2207 - accuracy: 0.9924 - val_loss: 0.6710 - val_accuracy: 0.8086
# Epoch 18/60
# 6/6 - 0s - loss: 0.1956 - accuracy: 0.9945 - val_loss: 0.6554 - val_accuracy: 0.8086
# Epoch 19/60
# 6/6 - 0s - loss: 0.1735 - accuracy: 0.9967 - val_loss: 0.6437 - val_accuracy: 0.8148
# Epoch 20/60
# 6/6 - 0s - loss: 0.1553 - accuracy: 0.9989 - val_loss: 0.6280 - val_accuracy: 0.8148
# Epoch 21/60
# 6/6 - 0s - loss: 0.1394 - accuracy: 0.9989 - val_loss: 0.6199 - val_accuracy: 0.8148
# Epoch 22/60
# 6/6 - 0s - loss: 0.1257 - accuracy: 1.0000 - val_loss: 0.6136 - val_accuracy: 0.8148
# Epoch 23/60
# 6/6 - 0s - loss: 0.1140 - accuracy: 1.0000 - val_loss: 0.6063 - val_accuracy: 0.8210
# Epoch 24/60
# 6/6 - 0s - loss: 0.1038 - accuracy: 1.0000 - val_loss: 0.5991 - val_accuracy: 0.8395
# Epoch 25/60
# 6/6 - 0s - loss: 0.0951 - accuracy: 1.0000 - val_loss: 0.5926 - val_accuracy: 0.8457
# Epoch 26/60
# 6/6 - 0s - loss: 0.0873 - accuracy: 1.0000 - val_loss: 0.5837 - val_accuracy: 0.8457
# Epoch 27/60
# 6/6 - 0s - loss: 0.0806 - accuracy: 1.0000 - val_loss: 0.5795 - val_accuracy: 0.8457
# Epoch 28/60
# 6/6 - 0s - loss: 0.0746 - accuracy: 1.0000 - val_loss: 0.5755 - val_accuracy: 0.8333
# Epoch 29/60
# 6/6 - 0s - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.5726 - val_accuracy: 0.8395
# Epoch 30/60
# 6/6 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 0.5707 - val_accuracy: 0.8395
# Epoch 31/60
# 6/6 - 0s - loss: 0.0604 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.8395
# Epoch 32/60
# 6/6 - 0s - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.8457
# Epoch 33/60
# 6/6 - 0s - loss: 0.0532 - accuracy: 1.0000 - val_loss: 0.5687 - val_accuracy: 0.8457
# Epoch 34/60
# 6/6 - 0s - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.8395
# Epoch 35/60
# 6/6 - 0s - loss: 0.0472 - accuracy: 1.0000 - val_loss: 0.5644 - val_accuracy: 0.8395
# Epoch 36/60
# 6/6 - 0s - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.5596 - val_accuracy: 0.8457
# Epoch 37/60
# 6/6 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.8457
# Epoch 38/60
# 6/6 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.5590 - val_accuracy: 0.8457
# Epoch 39/60
# 6/6 - 0s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.5586 - val_accuracy: 0.8457
# Epoch 40/60
# 6/6 - 0s - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.8457
# Epoch 41/60
# 6/6 - 0s - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.5577 - val_accuracy: 0.8457
# Epoch 42/60
# 6/6 - 0s - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.5556 - val_accuracy: 0.8457
# Epoch 43/60
# 6/6 - 0s - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.5544 - val_accuracy: 0.8457
# Epoch 44/60
# 6/6 - 0s - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.8457
# Epoch 45/60
# 6/6 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8457
# Epoch 46/60
# 6/6 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8457
# Epoch 47/60
# 6/6 - 0s - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.5519 - val_accuracy: 0.8457
# Epoch 48/60
# 6/6 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 0.8457
# Epoch 49/60
# 6/6 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.5506 - val_accuracy: 0.8457
# Epoch 50/60
# 6/6 - 0s - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.5503 - val_accuracy: 0.8457
# Epoch 51/60
# 6/6 - 0s - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 0.8457
# Epoch 52/60
# 6/6 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.5508 - val_accuracy: 0.8457
# Epoch 53/60
# 6/6 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.8457
# Epoch 54/60
# 6/6 - 0s - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8457
# Epoch 55/60
# 6/6 - 0s - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.8457
# Epoch 56/60
# 6/6 - 0s - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.5526 - val_accuracy: 0.8457
# Epoch 57/60
# 6/6 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8457
# Epoch 58/60
# 6/6 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8457
# Epoch 59/60
# 6/6 - 0s - loss: 0.0176 - accuracy: 1.0000 - val_loss: 0.5525 - val_accuracy: 0.8457
# Epoch 60/60
# 6/6 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.8457

# %%
# model's performance on test set
test_loss, test_acc = model_pca.evaluate(X_pca_test, y_test_labels, verbose=1)
# Out:
# 9/9 [==============================] - 0s 997us/step - loss: 0.4624 - accuracy: 0.8667
