# %% [markdown]
# # E13 - Analyze class homeworks

# %% [markdown]
# Elaborado por GRUPO 1:
#
# - Juanita Piraban Barbosa - 201216313
# - Lorena Morales Rodríguez - 202027957
# - Alejandro Barinas Guio - 201628859
# - Jaime Humberto Trujillo Perea - 201920366
# - Alexander Zapata Galindo - 201425426

# %%
#pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.15.3-py2.py3-none-any.whl (636 kB)
#      |████████████████████████████████| 636 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: nltk>=3.1 in /Users/lorenamorales/opt/anaconda3/lib/python3.8/site-packages (from textblob) (3.5)
# Requirement already satisfied: joblib in /Users/lorenamorales/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (0.16.0)
# Requirement already satisfied: click in /Users/lorenamorales/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /Users/lorenamorales/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.47.0)
# Requirement already satisfied: regex in /Users/lorenamorales/opt/anaconda3/lib/python3.8/site-packages (from nltk>=3.1->textblob) (2020.6.8)
# Installing collected packages: textblob
# Successfully installed textblob-0.15.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# Librerias
import pandas as pd
import numpy as np
import scipy as sp

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer

#conda install -c conda-forge wordcloud
from wordcloud import WordCloud

# %%
# Data
data = pd.read_excel('DataSet/Consolidado_respuestas_escribir_v2.xlsx',index_col=0)
data = pd.DataFrame(data)
data.head()
# Out:
#    Genero Carrera de pregrado Sector en el que trabaja  Edad  \
# ID
# 1       M         Matemáticas      Estudio de mercados  30.0
# 2       M                 NaN                      NaN   NaN
# 3       M                 NaN                      NaN   NaN
# 4       M         Estadistica               Financiero  28.0
# 5       M                 NaN                      NaN   NaN
#
#                 E1 - Examples of Time Series Analysis  \
# ID
# 1   Dentro de las diferentes aplicaciones que tien...
# 2                                                 NaN
# 3   Mercados energeticos: Tras la liberación y des...
# 4   Las series de tiempo son una colección de obse...
# 5   1. Actualmente, la empresa de mascotas Laika q...
#
#                                       E4 - Panel Data  \
# ID
# 1   La principal diferencia entre las series de ti...
# 2   una serie de tiempo se enfoca en un individio ...
# 3   Los datos de series de tiempo son un conjunto ...
# 4   Los datos de series de tiempo son un conjunto ...
# 5   Un conjunto de datos de una serie de tiempo co...
#
#                                    E6 - Decison Trees  \
# ID
# 1   Los arboles de decisión son herramienta de Mac...
# 2                                                 NaN
# 3                                                 NaN
# 4   Un árbol de decisión es una especie de mapa en...
# 5                                                 NaN
#
#                          E8 - Ensemble Trees Overview  \
# ID
# 1   Al proponer un método para realizar una predic...
# 2                                                 NaN
# 3   Los metodos de ensamble nos permiten mejorar e...
# 4   Los métodos de ensamble de modelos o métodos c...
# 5   Los modelos de ensamble consisten en mezclar l...
#
#                                        E10 - REST-API  \
# ID
# 1   Durante el desarrollo de soluciones dentro de ...
# 2   Un micro servicio es una parte de la arquitect...
# 3   Los microservicios defininen una nueva metodol...
# 4   Los microservicios son tanto un estilo de arqu...
# 5   Los microservicios son tanto un estilo de arqu...
#
#            E12 - Natural Language Processing Overview
# ID
# 1   La empresa kore.ai se especializa en la implem...
# 2                                                 NaN
# 3                                                 NaN
# 4   La función de autocompletar las palabras en Wh...
# 5                                                 NaN

# %% [markdown]
# # Exercise 13.1
#
# Analyze the writing patterns of each student

# %% [markdown]
# #### Descriptive Analysis

# %%
#Create the target feature (edad)
y1 = data.Edad.dropna()
print(y1.describe())
print('frequency table')
y1 = pd.cut(y1, [0, 28, 30, 34, 53], labels=['<28','28-30','30-34','>34'])
y1.value_counts()
# Out:
# count    27.000000
# mean     32.666667
# std       7.426564
# min      25.000000
# 25%      28.000000
# 50%      30.000000
# 75%      34.500000
# max      53.000000
# Name: Edad, dtype: float64
# frequency table
# <28      8
# >34      7
# 28-30    7
# 30-34    5
# Name: Edad, dtype: int64

# %%
y2 = data.Genero.dropna()
print('frequency table')
data['Genero'].value_counts()
# Out:
# frequency table
# M    28
# F    10
# Name: Genero, dtype: int64

# %%
y3 = data['Carrera de pregrado'].dropna()
print('frequency table')
data['Carrera de pregrado'].value_counts()
# Out:
# frequency table
# Ingeniería Industrial                               6
# Estadística                                         4
# Ingeniería Electrónica                              2
# Ingeniera de sistemas                               1
# Ing. Electrónica                                    1
# Ingenieria Indistrial, Admon Neg Internacionales    1
# Estadìstica                                         1
# Economista                                          1
# ECONOMIA                                            1
# Ingenieria Industrial                               1
# Estadistica                                         1
# Matemáticas                                         1
# Economía                                            1
# Finanzas                                            1
# Biología e Ingeniería Biomédica                     1
# Ingeniería Industrial y economía                    1
# Ingeniería de sistemas                              1
# Ingeniería de Sistemas                              1
# Name: Carrera de pregrado, dtype: int64

# %%
y4 = data['Sector en el que trabaja'].dropna()
print('frequency table')
data['Sector en el que trabaja'].value_counts()
# Out:
# frequency table
# Financiero                               9
# Fintech                                  2
# Salud                                    1
# Educación                                1
# Operaciones                              1
# Data Scientist - Banca                   1
# Público                                  1
# Pensiones                                1
# Consumo masivo                           1
# Infraestructura deTransporte             1
# Consumo Masivo                           1
# Cultura                                  1
# eléctrico y de comunicaciones            1
# Ingeniería de Software                   1
# Consultoría  de negocios y Tecnología    1
# Estudio de mercados                      1
# FINANCIERO                               1
# Telecomunicaciones                       1
# Name: Sector en el que trabaja, dtype: int64

# %% [markdown]
# ##### Tokenization: Matrices of Token by Homework

# %%
# Create the target feature (number of shares)

# Create document-term matrices
X1 = data['E1 - Examples of Time Series Analysis'].dropna()
X2 = data['E4 - Panel Data'].dropna()
X3 = data['E6 - Decison Trees'].dropna()
X4 = data['E8 - Ensemble Trees Overview'].dropna()
X5 = data['E10 - REST-API'].dropna()
X6 = data['E12 - Natural Language Processing Overview'].dropna()

# use CountVectorizer to create document-term matrices from X
vect1 = CountVectorizer()
X1_dtm = vect1.fit_transform(X1)

vect2 = CountVectorizer()
X2_dtm = vect2.fit_transform(X2)

vect3 = CountVectorizer()
X3_dtm = vect3.fit_transform(X3)

vect4 = CountVectorizer()
X4_dtm = vect4.fit_transform(X4)

vect5 = CountVectorizer()
X5_dtm = vect5.fit_transform(X5)

vect6 = CountVectorizer()
X6_dtm = vect6.fit_transform(X6)

# %%
# rows are comments, columns are terms (aka "tokens" or "features")
print('Exercise ( Number of comments , Number of terms)')
print('E1',X1_dtm.shape)
print('E4',X2_dtm.shape)
print('E6',X3_dtm.shape)
print('E8',X4_dtm.shape)
print('E10',X5_dtm.shape)
print('E12',X6_dtm.shape)
# Out:
# Exercise ( Number of comments , Number of terms)
# E1 (37, 1710)
# E4 (38, 1082)
# E6 (30, 1551)
# E8 (30, 1338)
# E10 (37, 1791)
# E12 (28, 1797)

# %%
print('Total terms E1',len(vect1.vocabulary_))
print('Word:Time')
print(vect1.vocabulary_)
# Out:
# Total terms E1 1710
# Word:Time
# {'dentro': 424, 'de': 396, 'las': 877, 'diferentes': 481, 'aplicaciones': 101, 'que': 1306, 'tiene': 1536, 'series': 1440, 'tiempo': 1533, 'en': 547, 'la': 872, 'vida': 1657, 'real': 1316, 'se': 1409, 'encuentran': 552, 'como': 262, 'el': 531, 'precio': 1200, 'cualquier': 358, 'activo': 21, 'lo': 901, 'largo': 876, 'estas': 617, 'son': 1474, 'gran': 743, 'importancia': 802, 'dado': 387, 'reflejan': 1348, 'por': 1192, 'general': 726, 'mercados': 972, 'medio': 961, 'bolsas': 170, 'valores': 1630, 'new': 1055, 'york': 1690, 'tokio': 1546, 'más': 1027, 'localmente': 903, 'colombia': 257, 'perú': 1169, 'análisis': 97, 'relacionado': 1361, 'con': 284, 'este': 619, 'tipo': 1540, 'siempre': 1450, 'ha': 754, 'tenido': 1526, 'un': 1590, 'interés': 854, 'económico': 518, 'los': 906, 'volúmenes': 1678, 'dinero': 486, 'están': 637, 'presentes': 1215, 'importantes': 804, 'del': 417, 'mundo': 1024, 'otra': 1103, 'parte': 1124, 'medicina': 955, 'es': 578, 'importante': 803, 'monitorear': 1005, 'algunos': 67, 'signos': 1454, 'pueden': 1292, 'ser': 1437, 'presión': 1217, 'arterial': 111, 'glucosa': 739, 'hormonas': 778, 'produce': 1244, 'sistema': 1462, 'endocrino': 554, 'saturación': 1406, 'oxígeno': 1108, 'entre': 566, 'otras': 1104, 'seguimiento': 1419, 'predicción': 1206, 'permite': 1158, 'realizar': 1324, 'diagnósticos': 469, 'tempranos': 1518, 'enfermedades': 558, 'silenciosas': 1457, 'graves': 745, 'problemas': 1240, 'cardiacos': 211, 'último': 1705, 'otro': 1105, 'ejemplo': 529, 'donde': 505, 'necesite': 1048, 'comportamientos': 274, 'naturaleza': 1039, 'puntualmente': 1298, 'velocidad': 1644, 'viento': 1660, 'caudal': 218, 'rio': 1392, 'cantidad': 201, 'partículas': 1132, 'nocivas': 1059, 'aire': 54, 'densidad': 423, 'ciertos': 232, 'líquidos': 913, 'atmosférica': 128, 'particularmente': 1129, 'analizarlas': 85, 'ámbitos': 1692, 'ambientales': 77, 'debido': 400, 'ayuda': 143, 'disipar': 490, 'producidas': 1245, 'actores': 23, 'contaminantes': 314, 'parque': 1123, 'automotor': 140, 'una': 1591, 'ciudad': 233, 'todos': 1545, 'sus': 1495, 'agentes': 47, 'motos': 1013, 'carros': 213, 'servicio': 1441, 'público': 1305, 'etc': 642, 'industrias': 821, 'región': 1355, 'dada': 386, 'presentar': 1214, 'producción': 1243, 'grandes': 744, 'masas': 934, 'efectos': 525, 'naturales': 1038, 'presentan': 1213, 'épocas': 1696, 'sequía': 1435, 'mismo': 990, 'incrementar': 812, 'contaminación': 313, 'lugar': 910, 'energeticos': 555, 'tras': 1570, 'liberación': 882, 'desregulación': 454, 'muchos': 1016, 'energéticos': 556, 'precios': 1201, 'energía': 557, 'han': 763, 'cobrado': 247, 'pues': 1293, 'estos': 627, 'comportan': 275, 'forma': 698, 'volátil': 1677, 'ya': 1689, 'insumo': 840, 'todas': 1543, 'economías': 516, 'pronóstico': 1263, 'no': 1058, 'sólo': 1498, 'para': 1119, 'toma': 1547, 'decisiones': 403, 'sino': 1460, 'otros': 1106, 'sectores': 1414, 'económicos': 519, 'petróleo': 1171, 'variable': 1632, 'explicativa': 660, 'movimientos': 1015, 'tasa': 1507, 'cambio': 193, 'dólar': 513, 'americano': 78, 'monedas': 1001, 'principales': 1232, 'mundiales': 1023, 'estudio': 634, 'variables': 1633, 'aportes': 104, 'hídricos': 786, 'demanda': 418, 'actividades': 20, 'realizadas': 1320, 'área': 1694, 'modelos': 995, 'mercado': 971, 'aplica': 99, 'planeación': 1176, 'evaluación': 643, 'inversiones': 860, 'valoración': 1629, 'recursos': 1340, 'estrategias': 629, 'comerciales': 260, 'iot': 865, 'últimos': 1706, 'años': 145, 'evolución': 650, 'internet': 850, 'of': 1081, 'things': 1532, 'resultado': 1382, 'despliegue': 452, 'sensores': 1431, 'produciendo': 1247, 'continuamente': 321, 'datos': 394, 'crea': 346, 'enorme': 561, 'búsquedas': 182, 'patrones': 1136, 'busqueda': 180, 'anomalias': 87, 'deteccion': 457, 'podemos': 1185, 'encontrar': 550, 'estaticas': 618, 'dinamicas': 485, 'outliers': 1107, 'astronomia': 121, 'astronómicos': 123, 'algo': 64, 'si': 1448, 'comparan': 263, 'estándar': 638, 'utilizan': 1618, 'areas': 109, 'ciencia': 229, 'negocios': 1053, 'al ...

# %%
print('Total terms E4',len(vect2.vocabulary_))
print('Word:Time')
print(vect2.vocabulary_)
# Out:
# Total terms E4 1082
# Word:Time
# {'la': 569, 'principal': 775, 'diferencia': 303, 'entre': 373, 'las': 573, 'series': 899, 'de': 256, 'tiempo': 966, 'los': 584, 'datos': 255, 'panel': 712, 'es': 379, 'que': 810, 'en': 356, 'se': 879, 'analiza': 57, 'regularmente': 844, 'solo': 927, 'variable': 1033, 'resultado': 864, 'el': 346, 'intervalo': 556, 'definido': 264, 'por': 754, 'otro': 705, 'lado': 570, 'dado': 249, 'son': 929, 'observaciones': 678, 'mismos': 629, 'individuos': 539, 'estudio': 415, 'lo': 581, 'cual': 237, 'permite': 735, 'analizar': 59, 'forma': 466, 'más': 655, 'detallada': 286, 'completa': 180, 'cambios': 122, 'nivel': 665, 'total': 985, 'como': 176, 'están': 417, 'desagregados': 274, 'puede': 802, 'eliminar': 349, 'sesgo': 904, 'trabajar': 990, 'con': 188, 'agrupados': 45, 'además': 34, 'pueden': 803, 'incorporar': 530, 'características': 131, 'inobservables': 550, 'efectos': 336, 'temporales': 955, 'forman': 467, 'parte': 718, 'heterogeneidad': 497, 'no': 668, 'observable': 677, 'general': 477, 'caso': 133, 'objetivo': 676, 'dentro': 271, 'desventajas': 285, 'respecto': 862, 'análisis': 68, 'principalmente': 777, 'obtención': 686, 'procesamiento': 780, 'información': 544, 'permanencia': 734, 'del': 265, 'necesario': 659, 'una': 1006, 'serie': 898, 'enfoca': 363, 'un': 1005, 'individio': 534, 'mientras': 623, 'enfocan': 364, 'multiples': 649, 'conjunto': 192, 'consta': 205, 'individuo': 538, 'múltiples': 656, 'intervalos': 557, 'obtenidas': 687, 'refiere': 832, 'estos': 404, 'combinan': 171, 'dimensión': 310, 'temporal': 954, 'otra': 703, 'transversal': 991, 'contiene': 214, 'sobre': 922, 'fenómenos': 450, 'momento': 635, 'determinado': 290, 'exiten': 437, 'varias': 1038, 'ventajas': 1046, 'modelar': 632, 'comportamientos': 184, 'comunes': 186, 'individuales': 536, 'grupos': 486, 'contienen': 215, 'variabilidad': 1032, 'eficiencia': 337, 'puros': 806, 'detectar': 287, 'medir': 609, 'estadísticos': 395, 'puras': 805, 'minimizar': 624, 'sesgos': 905, 'estimación': 401, 'surgir': 941, 'agregación': 42, 'sola': 925, 'podemos': 750, 'citar': 147, 'siguientes': 913, 'ejemplos': 345, 'microeconomía': 620, 'pib': 748, 'varios': 1039, 'países': 729, 'desempleo': 279, 'diferentes': 305, 'estados': 393, 'estudios': 416, 'dinámica': 311, 'ingresos': 548, 'saldos': 873, 'cuenta': 242, 'corriente': 225, 'internacional': 554, 'macroeconomia': 588, 'tablas': 944, 'comercio': 173, 'socioeconómicas': 923, 'mundiales': 652, 'tipos': 974, 'cambio': 121, 'epidemiologia': 375, 'estadisticas': 391, 'salud': 875, 'seguros': 888, 'públicos': 809, 'tasas': 950, 'supervivencia': 939, 'enfermedades': 362, 'desarrollo': 275, 'bienestar': 103, 'infantil': 541, 'finanzas': 460, 'precios': 763, 'acciones': 28, 'empresa': 354, 'volatilidades': 1059, 'mercado': 616, 'país': 728, 'presentar': 768, 'algunos': 50, 'problemas': 779, 'modelos': 634, 'basados': 99, 'abandono': 23, 'muestra': 643, 'ciertos': 144, 'posible': 760, 'realizar': 818, 'su': 935, 'seguimiento': 884, 'largo': 572, 'si': 907, 'esto': 403, 'ocurre': 691, 'sistemática': 920, 'proporcionar': 795, 'censura': 137, 'solucionar': 928, 'mediante': 602, 'observación': 679, 'muy': 654, 'similares': 914, 'cohortes': 163, 'aleatoriedad': 47, 'implicaría': 519, 'decisiones': 260, 'erróneas': 378, 'representativas': 858, 'desequilibrios': 281, 'haga': 493, 'tenga': 961, 'otros': 706, 'equilibrado': 376, 'incompleto': 527, 'valores': 1031, 'momentos': 636, 'tal': 945, 'debe': 257, 'recopilarse': 828, 'regulares': 843, 'decir': 258, 'diaria': 295, 'informes': 545, 'semanal': 889, 'cifras': 145, 'oferta': 693, 'monetaria': 638, 'mensual': 613, 'índice': 1074, 'al': 46, 'consumidor': 209, 'ipc': 561, 'trimestral': 997, 'anual': 64, 'unidades': 1009, 'observado': 680, 'distintos': 319, 'dinámico': 313, 'encuesta': 359, 'condiciones': 191, 'vida': 1052, 'presentan': 767, 'algunas': 49, 'mayor': 598, 'número': 675, 'capturar': 127, 'reduce': 830, 'colinealidad': 164, 'variables': 1034, 'explicativas': 440, 'cada': 115, 'comunidad ...

# %%
print('Total terms E6',len(vect3.vocabulary_))
print('Word:Time')
print(vect3.vocabulary_)
# Out:
# Total terms E6 1551
# Word:Time
# {'los': 861, 'arboles': 95, 'de': 375, 'decisión': 383, 'son': 1358, 'herramienta': 730, 'machine': 867, 'learning': 842, 'supervisado': 1378, 'que': 1171, 'permite': 1043, 'partir': 1032, 'diferentes': 443, 'decisiones': 382, 'nodos': 970, 'ir': 822, 'tomando': 1430, 'basadas': 132, 'en': 502, 'variables': 1498, 'cuantitativas': 351, 'cualitativas': 347, 'para': 1021, 'llegar': 856, 'un': 1458, 'nodo': 969, 'final': 645, 'donde': 470, 'ser': 1320, 'la': 834, 'tomada': 1428, 'dicha': 436, 'observación': 993, 'dentro': 398, 'usos': 1471, 'tienen': 1419, 'se': 1285, 'encuentran': 507, 'problemas': 1133, 'clasificación': 227, 'regresión': 1217, 'finalidad': 647, 'estos': 582, 'es': 536, 'realizar': 1194, 'generar': 700, 'modelo': 918, 'clasificar': 232, 'dos': 471, 'más': 940, 'respuestas': 1256, 'ejemplos': 490, 'comunes': 275, 'utilizando': 1482, 'información': 792, 'encuentra': 506, 'base': 136, 'datos': 374, 'bancos': 128, 'determinar': 430, 'retención': 1262, 'clientes': 235, 'deferentes': 385, 'tipos': 1421, 'servicios': 1323, 'ofrecidos': 1002, 'por': 1079, 'el': 493, 'banco': 127, 'como': 253, 'lo': 857, 'tarjetas': 1395, 'crédito': 339, 'otro': 1013, 'ejemplo': 489, 'caracterización': 190, 'enfermedades': 510, 'considerando': 297, 'síntomas': 1389, 'presentan': 1120, 'pacientes': 1019, 'puede': 1161, 'cáncer': 362, 'incluso': 770, 'coronarias': 320, 'otra': 1011, 'parte': 1026, 'permiten': 1044, 'estimar': 580, 'valor': 1490, 'interese': 804, 'una': 1459, 'variable': 1497, 'continua': 313, 'entre': 523, 'podemos': 1069, 'encontrar': 505, 'nuevamente': 978, 'ámbito': 1535, 'bancario': 125, 'estimación': 577, 'cantidad': 183, 'saldo': 1279, 'le': 840, 'otorgar': 1010, 'cliente': 234, 'este': 574, 'no': 968, 'default': 384, 'seria': 1321, 'visitas': 1520, 'artículos': 99, 'electrónicos': 494, 'características': 192, 'titulo': 1422, 'imágenes': 768, 'sentimiento': 1316, 'general': 695, 'articulo': 97, 'otros': 1014, 'versatilidad': 1516, 'practicidad': 1095, 'algoritmos': 52, 'también': 1392, 'puedan': 1160, 'ensambles': 516, 'con': 277, 'otras': 1012, 'técnicas': 1453, 'tener': 1403, 'mayor': 881, 'potencia': 1091, 'predicción': 1106, 'punto': 1163, 'favor': 639, 'pueden': 1162, 'potenciar': 1093, 'medio': 892, 'capten': 189, 'mejor': 894, 'forma': 660, 'variabilidad': 1496, 'entrenamiento': 527, 'su': 1361, 'árbol': 1537, 'especie': 553, 'mapa': 872, 'muestra': 932, 'cada': 169, 'las': 839, 'opciones': 1005, 'posibles': 1087, 'sus': 1381, 'resultados': 1260, 'tomar': 1431, 'negocio': 962, 'ya': 1533, 'comparar': 256, 'acciones': 9, 'según': 1302, 'costos': 330, 'probabilidades': 1129, 'beneficios': 142, 'árboles': 1538, 'comienzan': 251, 'del': 391, 'cual': 345, 'salen': 1280, 'función': 678, 'presenten': 1122, 'estas': 572, 'existen': 618, 'tres': 1447, 'representa': 1237, 'cuadrado': 342, 'tomará': 1432, 'probabilidad': 1128, 'está': 592, 'representado': 1239, 'círculo': 364, 'ciertos': 222, 'terminales': 1409, 'triangular': 1448, 'resultado': 1259, 'definitivo': 390, 'ruta': 1274, 'principales': 1127, 'ventajas': 1512, 'utilizar': 1483, 'tu': 1449, 'proceso': 1136, 'tipo': 1420, 'diagrama': 434, 'evidentes': 609, 'seguro': 1301, 'mayoría': 883, 'ellas': 496, 'te': 1398, 'han': 725, 'pasado': 1035, 'cabeza': 168, 'simples': 1342, 'entender': 517, 'interpretar': 813, 'si': 1332, 'demasiado': 392, 'grande': 710, 'visualizarse': 1523, 'vistazo': 1521, 'eso': 549, 'facilita': 635, 'mucho': 929, 'entendimiento': 518, 'requiere': 1245, 'preparación': 1118, 'excesivamente': 612, 'compleja': 260, 'válido': 1527, 'tanto': 1393, 'agregar': 33, 'nuevas': 979, 'existentes': 621, 'fácilmente': 687, 'combinables': 242, 'herramientas': 731, 'tomas': 1433, 'respuesta': 1255, 'algoritmo': 51, 'justificable': 830, 'lógica': 864, 'booleana': 151, 'implementada': 760, 'él': 1540, 'cuando': 349, 'predicho': 1109, 'clase': 224, 'pertenecen': 1051, 'considerar': 298, 'número': 987, 'real': 1190, 'precio': 1098, 'casa': 197, 'días': 480, 'estan ...

# %%
print('Total terms E8',len(vect4.vocabulary_))
print('Word:Time')
print(vect4.vocabulary_)
# Out:
# Total terms E8 1338
# Word:Time
# {'al': 31, 'proponer': 979, 'un': 1245, 'método': 787, 'para': 856, 'realizar': 1020, 'una': 1246, 'predicción': 929, 'este': 489, 'debe': 323, 'usar': 1258, 'como': 207, 'base': 116, 'partición': 864, 'de': 322, 'la': 684, 'información': 650, 'lo': 704, 'cual': 299, 'en': 416, 'algunos': 43, 'los': 711, 'casos': 170, 'pueden': 988, 'presentar': 940, 'problemas': 954, 'selección': 1104, 'muestra': 777, 'entrenamiento': 451, 'del': 336, 'algoritmo': 39, 'adicionalmente': 15, 'si': 1120, 'se': 1089, 'consideran': 251, 'diferentes': 367, 'métodos': 788, 'el': 403, 'mismo': 761, 'conjunto': 239, 'encontrar': 419, 'soluciones': 1151, 'problema': 953, 'que': 995, 'está': 505, 'intentado': 661, 'solucionar': 1150, 'evitar': 521, 'esta': 479, 'ambigüedad': 51, 'hace': 601, 'uso': 1260, 'teorema': 1206, 'nos': 808, 'dice': 360, 'cualquier': 302, 'combinación': 198, 'modelos': 768, 'sea': 1090, 'mejor': 735, 'clasificación': 184, 'aleatoria': 32, 'dicha': 361, 'es': 461, 'cualquiera': 303, 'evaluados': 514, 'forma': 554, 'individual': 643, 'así': 91, 'tenemos': 1200, 'diferente': 366, 'tipos': 1218, 'ensamblajes': 432, 'primero': 944, 'no': 805, 'necesita': 797, 'generar': 583, 'aparte': 64, 'utilizando': 1273, 'inicial': 651, 'bagging': 109, 'donde': 385, 'bootstrap': 126, 'muestras': 778, 'finalmente': 548, 'generando': 582, 'luego': 712, 'van': 1284, 'ser': 1113, 'agregados': 20, 'por': 911, 'medio': 733, 'ensamblaje': 431, 'procedimiento': 955, 'permite': 878, 'reducir': 1034, 'considerable': 249, 'varianza': 1289, 'mejorando': 737, 'precisión': 923, 'obteniendo': 826, 'resultados': 1068, 'muy': 782, 'similares': 1130, 'cuando': 304, 'cros': 293, 'validación': 1278, 'otra': 843, 'parte': 861, 'lugar': 713, 'tener': 1201, 'algoritmos': 40, 'misma': 760, 'entonces': 443, 'podemos': 894, 'hacer': 603, 'ensamblar': 435, 'varios': 1292, 'clasificadores': 186, 'votación': 1306, 'ponderada': 904, 'desempeño': 351, 'cada': 152, 'uno': 1250, 'mse': 772, 'regresión': 1041, 'gini': 585, 'tanto': 1193, 'permiten': 879, 'reducción': 1031, 'directamente': 369, 'metodología': 750, 'sin': 1135, 'costos': 289, 'adicionales': 14, 'mejora': 736, 'puede': 987, 'obtener': 822, 'haciendo': 605, 'proceso': 957, 'paralelo': 858, 'bootstraps': 129, 'independientes': 640, 'utilizar': 1274, 'dos': 386, 'ensambles': 440, 'vistos': 1304, 'eficiente': 398, 'con': 229, 'respecto': 1061, 'tiempo': 1211, 'procesamiento': 956, 'metodos': 751, 'ensamble': 439, 'mejorar': 738, 'rendimiento': 1047, 'predictivo': 933, 'basados': 114, 'árboles': 1324, 'tambien': 1189, 'les': 691, 'conoce': 241, 'combinados': 200, 'aprendizaje': 77, 'predicciones': 928, 'mejores': 741, 'las': 687, 'podrian': 897, 'individualmente': 645, 'entre': 447, 'arboles': 82, 'estan': 486, 'random': 1005, 'forest': 553, 'caso': 169, 'especial': 473, 'boosting': 123, 'conformado': 236, 'ensemble': 441, 'individuales': 644, 'entrenado': 449, 'extraida': 539, 'datos': 321, 'originales': 842, 'metodo': 749, 'bootstraping': 127, 'busca': 138, 'resolver': 1058, 'estadístico': 485, 'tradicionales': 1233, 'equilibrio': 456, 'sesgo': 1115, 'radica': 1002, 'medida': 732, 'aumenta': 96, 'complejidad': 214, 'modelo': 767, 'mas': 723, 'flexible': 552, 'adaptarce': 11, 'observaciones': 818, 'su': 1159, 'capacidad': 163, 'predictiva': 932, 'pero': 881, 'determinado': 356, 'punto': 992, 'flexibilidad': 551, 'genera': 574, 'overfitting': 853, 'ajusta': 25, 'ya': 1319, 'capaz': 165, 'predecir': 926, 'correctamente': 277, 'nuevas': 812, 'buscaremos': 143, 'siempre': 1122, 'buen': 133, 'combinar': 203, 'multiples': 780, 'nuevo': 813, 'logran': 708, 'otros': 846, 'ensable': 427, 'son': 1153, 'todos': 1222, 'forman': 555, 'combinacion': 196, 'participan': 863, 'aportando': 71, 'valor': 1280, 'final': 547, 'toma': 1223, 'media': 729, 'todas': 1220, 'variables': 1287, 'continuas': 267, 'clase': 182, 'más': 783, 'frecuente': 559, 'categóricas': 172, 'utiliza': 1265, 'múltiples': 793, 'sencillos': 1106, 'llamados': 700, 'wea ...

# %%
print('Total terms E10',len(vect5.vocabulary_))
print('Word:Time')
print(vect5.vocabulary_)
# Out:
# Total terms E10 1791
# Word:Time
# {'durante': 599, 'el': 624, 'desarrollo': 503, 'de': 444, 'soluciones': 1598, 'dentro': 478, 'las': 1027, 'empresas': 639, 'se': 1532, 'encuentran': 653, 'varias': 1741, 'dificultades': 549, 'al': 76, 'tratar': 1687, 'solventar': 1600, 'todas': 1663, 'posibles': 1327, 'necesidades': 1190, 'en': 641, 'un': 1704, 'solo': 1595, 'sistema': 1584, 'servicio': 1556, 'tener': 1644, 'grandes': 884, 'tiene': 1658, 'paquete': 1262, 'cada': 203, 'una': 1705, 'por': 1322, 'tanto': 1632, 'momento': 1154, 'actualizar': 36, 'mejorar': 1115, 'alguna': 80, 'parte': 1269, 'especifica': 723, 'la': 1024, 'solución': 1599, 'encuentra': 652, 'con': 314, 'gran': 882, 'numero': 1211, 'validaciones': 1734, 'sobre': 1587, 'objetos': 1214, 'que': 1416, 'no': 1201, 'fueron': 840, 'modificados': 1148, 'para': 1264, 'experiencia': 782, 'del': 470, 'cliente': 245, 'como': 272, 'desarrollador': 495, 'arquitectura': 132, 'micro': 1131, 'servicios': 1557, 'cual': 411, 'permite': 1291, 'medio': 1110, 'varios': 1743, 'ellos': 632, 'llegar': 1055, 'misma': 1137, 'pero': 1295, 'diferentes': 547, 'componentes': 295, 'donde': 595, 'componente': 294, 'es': 688, 'desarrollada': 492, 'liberada': 1036, 'escalada': 694, 'forma': 828, 'individual': 960, 'uno': 1712, 'estos': 752, 'encargar': 646, 'propósito': 1388, 'muy': 1172, 'específico': 728, 'vivirán': 1764, 'todo': 1664, 'mismo': 1139, 'ambiente': 98, 'todos': 1665, 'deberán': 448, 'poder': 1313, 'comunicarse': 310, 'dar': 440, 'información': 965, 'necesaria': 1185, 'salida': 1530, 'su': 1608, 'proceso': 1360, 'otro': 1257, 'lo': 1062, 'recibirá': 1434, 'logrando': 1069, 'así': 146, 'desglosar': 519, 'complejo': 284, 'procesos': 1361, 'mucho': 1165, 'más': 1173, 'simples': 1575, 'independientes': 956, 'hacer': 897, 'mantenimiento': 1096, 'mejora': 1113, 'debería': 449, 'ser': 1553, 'manera': 1087, 'transparente': 1684, 'rápida': 1521, 'sin': 1580, 'afectar': 62, 'los': 1071, 'otros': 1258, 'general': 866, 'identifican': 919, 'aspectos': 145, 'permiten': 1292, 'definir': 466, 'desagregar': 490, 'subprocesos': 1610, 'partes': 1270, 'trabajo': 1677, 'específicos': 729, 'manejables': 1085, 'haciendo': 901, 'está': 760, 'divido': 589, 'principal': 1345, 'sea': 1533, 'solucionado': 1596, 'pequeño': 1286, 'sirve': 1583, 'solucionar': 1597, 'este': 746, 'subproceso': 1609, 'son': 1601, 'flexibles': 823, 'eficientes': 611, 'hace': 895, 'mejor': 1112, 'posible': 1326, 'esto': 751, 'mediante': 1107, 'implementación': 931, 'comunicación': 307, 'nube': 1207, 'busca': 193, 'operacionalizar': 1230, 'encontrados': 648, 'analítica': 103, 'modelos': 1146, 'analíticos': 105, 'análisis': 111, 'adhoc': 48, 'fuentes': 839, 'datos': 442, 'adquiridas': 58, 'cumplimiento': 425, 'objetivo': 1213, 'propone': 1385, 'investigar': 1010, 'práctica': 1395, 'ponen': 1319, 'disposición': 571, 'resultado': 1505, 'encontrado': 647, 'través': 1689, 'apis': 113, 'conectadas': 323, 'directa': 556, 'usuario': 1724, 'final': 816, 'pueda': 1400, 'consumo': 362, 'mas': 1102, 'microservicios': 1134, 'nace': 1181, 'necesidad': 1189, 'actual': 29, 'sufre': 1616, 'demanda': 473, 'si': 1564, 'monolitico': 1157, 'entonces': 675, 'aprovecha': 125, 'funcionan': 848, 'independiente': 954, 'comunican': 308, 'tareas': 1634, 'realizan': 1430, 'colocar': 260, 'modelo': 1145, 'producción': 1363, 'disponible': 569, 'eslabón': 711, 'cadena': 204, 'analítico': 104, 'eslabones': 710, 'puede': 1402, 'empaquetar': 634, 'conectados': 324, 'maneja': 1083, 'tal': 1626, 'microservicio': 1133, 'sola': 1591, 'función': 853, 'esta': 732, 'garantiza': 862, 'puedan': 1401, 'ejecutar': 617, 'características': 220, 'importantes': 943, 'realizar': 1431, 'tipo': 1660, 'tienen': 1659, 'particularidad': 1273, 'van': 1739, 'buscar': 195, 'escalabilidad': 691, 'fácilmente': 859, 'resulta': 1504, 'efectiva': 606, 'otra': 1255, 'organización': 1241, 'innovación': 973, 'acelerar': 17, 'tiempos': 1656, 'comercialización': 270, 'nuevos': 1210, 'productos': 1367, 'tengan': 1646, 'nivel': 1200, 'crecer ...

# %%
print('Total terms E12',len(vect6.vocabulary_))
print('Word:Time')
print(vect6.vocabulary_)
# Out:
# Total terms E12 1797
# Word:Time
# {'la': 961, 'empresa': 592, 'kore': 960, 'ai': 61, 'se': 1499, 'especializa': 667, 'en': 594, 'implementación': 880, 'de': 458, 'asistentes': 143, 'virtuales': 1763, 'diferentes': 521, 'sectores': 1504, 'como': 317, 'lo': 1001, 'son': 1578, 'bancos': 196, 'seguros': 1512, 'empresas': 593, 'del': 471, 'sector': 1503, 'salud': 1493, 'el': 573, 'retail': 1467, 'donde': 546, 'uno': 1709, 'los': 1005, 'canales': 236, 'comunicación': 346, 'es': 641, 'por': 1292, 'medio': 1051, 'un': 1705, 'chat': 274, 'con': 352, 'asesor': 140, 'parte': 1240, 'su': 1589, 'estrategia': 687, 'mercadeo': 1061, 'tienen': 1651, 'asistente': 142, 'virtual': 1762, 'que': 1383, 'funciona': 781, 'tanto': 1617, 'página': 1380, 'web': 1779, 'muestra': 1112, 'las': 967, 'capacidades': 241, 'tener': 1636, 'soluciones': 1574, 'adaptables': 32, 'cada': 231, 'necesidad': 1138, 'https': 856, 'conversational': 404, 'what': 1781, 'is': 954, 'assistant': 154, 'función': 786, 'autocompletar': 164, 'palabras': 1234, 'whatsapp': 1782, 'cuando': 443, 'persona': 1269, 'esta': 672, 'escribiendo': 650, 'correos': 417, 'hotmail': 854, 'gpt': 803, 'openai': 1200, 'generative': 800, 'pre': 1302, 'trained': 1677, 'transformer': 1683, 'una': 1706, 'inteligencia': 932, 'artificial': 132, 'código': 451, 'abierto': 10, 'creada': 429, 'febrero': 748, '2019': 4, 'traduce': 1675, 'texto': 1644, 'responde': 1454, 'preguntas': 1315, 'resume': 1462, 'pasajes': 1246, 'genera': 791, 'salidas': 1491, 'nivel': 1154, 'aunque': 162, 'veces': 1748, 'no': 1160, 'distingue': 536, 'humanos': 861, 'puede': 1374, 'volverse': 1773, 'repetitivo': 1439, 'sin': 1554, 'sentido': 1522, 'largos': 966, 'aprendiz': 119, 'propósito': 1362, 'general': 793, 'fue': 778, 'entrenado': 631, 'específicamente': 669, 'para': 1238, 'realizar': 1401, 'ninguna': 1153, 'estas': 683, 'tareas': 1618, 'capacidad': 240, 'llevarlas': 999, 'cabo': 230, 'extensión': 729, 'sintetizar': 1557, 'precisión': 1304, 'siguiente': 1544, 'elemento': 577, 'secuencia': 1505, 'arbitraria': 127, 'creado': 430, 'ampliación': 85, 'directa': 525, 'modelo': 1093, '2018': 3, 'aumento': 161, 'diez': 519, 'número': 1178, 'parámetros': 1245, 'tamaño': 1613, 'conjunto': 364, 'datos': 457, 'entrenamiento': 633, 'arquitectura': 130, 'implementa': 879, 'red': 1418, 'neuronal': 1147, 'profunda': 1350, 'concretamente': 356, 'transformador': 1681, 'utiliza': 1726, 'atención': 158, 'lugar': 1008, 'anteriores': 102, 'arquitecturas': 131, 'basadas': 203, 'recurrencia': 1415, 'convolución': 410, 'mecanismos': 1043, 'permiten': 1265, 'al': 62, 'centrarse': 264, 'selectivamente': 1517, 'segmentos': 1507, 'entrada': 625, 'predice': 1309, 'más': 1118, 'relevantes': 1435, 'este': 684, 'permite': 1264, 'gran': 810, 'paralelización': 1239, 'supera': 1602, 'pruebas': 1367, 'modelos': 1094, 'basados': 205, 'rnn': 1475, 'cnn': 300, 'lstm': 1006, 'publicó': 1371, 'versión': 1754, 'completa': 327, 'lenguaje': 976, '500': 7, 'millones': 1080, 'noviembre': 1168, 'le': 969, 'seguiría': 1509, '175': 1, 'mil': 1079, 'revelado': 1471, 'público': 1382, '2020': 5, 'cuyo': 449, 'fuente': 779, 'nunca': 1177, 'ha': 819, 'puesto': 1376, 'disposición': 533, 'acceso': 14, 'proporciona': 1357, 'exclusivamente': 713, 'través': 1689, 'api': 109, 'ofrecida': 1193, 'microsoft': 1073, 'www': 1785, 'grammarly': 807, 'com': 308, 'aplicación': 111, 'tiene': 1650, 'principal': 1332, 'corregir': 413, 'mejorar': 1056, 'ortografía': 1222, 'gramática': 808, 'electrónicos': 575, 'textos': 1645, 'escriba': 647, 'usuario': 1723, 'aplicativo': 114, 'instala': 926, 'complemento': 326, 'navegadores': 1134, 'vez': 1755, 'empieza': 588, 'escribir': 652, 'automáticamente': 170, 'identificar': 869, 'posibles': 1297, 'errores': 640, 'gramaticales': 806, 'funcionamiento': 782, 'basa': 201, 'aspectos': 152, 'principales': 1333, 'concepción': 353, 'composición': 333, 'revisión': 1472, 'comprensión': 336, 'equipo': 637, 'desarrollo': 488, 'está': 701, 'conformado': 361, 'analistas': 88, 'liguistas': 984, 'quienes': 1 ...

# %%
print(X1_dtm.todense()[0].argmax())
print(X2_dtm.todense()[0].argmax())
print(X3_dtm.todense()[0].argmax())
print(X4_dtm.todense()[0].argmax())
print(X5_dtm.todense()[0].argmax())
print(X6_dtm.todense()[0].argmax())
# Out:
# 396
# 256
# 375
# 322
# 444
# 458

# %%
print(vect1.get_feature_names()[396])
print(vect2.get_feature_names()[256])
print(vect3.get_feature_names()[375])
print(vect4.get_feature_names()[322])
print(vect5.get_feature_names()[444])
print(vect6.get_feature_names()[458])
# Out:
# de
# de
# de
# de
# de
# de

# %% [markdown]
# ### OJO PARA BORRAR:
# Validar con el team si repetimos esto para los 6 vectores antes del stop wording

# %%
# include 1-grams and 2-grams
vect1 = CountVectorizer(ngram_range=(1, 3))
X1_dtm = vect1.fit_transform(X1)
X1_dtm.shape
# Out:
# (37, 13060)

# %%
# last 60 features
print(vect1.get_feature_names()[-13060:-13000])
# Out:
# ['10', '10 años', '10 años se', '12', '12 horas', '12 horas cada', '12 meses', '12 meses de', '19', '19 partir', '19 partir de', '2010', '2010 2019', '2010 2019 determinar', '2019', '2019 determinar', '2019 determinar el', '30', '30 años', '30 años serie', '30 ciudades', '30 ciudades de', '30 días', '30 días bien', 'abastecimiento', 'abastecimiento se', 'abastecimiento se analiza', 'abierto', 'abierto omas', 'abierto omas con', 'abruptos', 'abruptos que', 'abruptos que se', 'académica', 'académica en', 'académica en particular', 'académico', 'académico en', 'académico en particular', 'accionario', 'accionario las', 'accionario las acciones', 'accionario se', 'accionario se construye', 'acciones', 'acciones análisis', 'acciones análisis demográficos', 'acciones en', 'acciones en dicho', 'acciones en el', 'acciones en la', 'acciones es', 'acciones es estacionario', 'acciones que', 'acciones que lo', 'acciones que mejor', 'acciones si', 'acciones si el', 'acciones través', 'acciones través del']

# %% [markdown]
# # Stopword Removal

# %% [markdown]
# #### Word Cloud

# %%
# features - "E1 - Examples of Time Series Analysis"
df1 = vect1.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df1)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E1 - Examples of Time Series Analysis")
plt.axis("off")
plt.show()

# %%
# features - "E4 - Panel Data"
df2 = vect2.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df2)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E4 - Panel Data")
plt.axis("off")
plt.show()

# %%
# features - "E6 - Decison Trees"
df3 = vect3.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df3)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E6 - Decison Trees")
plt.axis("off")
plt.show()

# %%
# features - "E8 - Ensemble Trees Overview"
df4 = vect4.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df4)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E8 - Ensemble Trees Overview")
plt.axis("off")
plt.show()

# %%
# features - "E10 - REST-API"
df5 = vect5.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df5)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E10 - REST-API")
plt.axis("off")
plt.show()

# %%
# features - "E12 - Natural Language Processing Overview"
df6 = vect6.get_feature_names()

#Creating the text variable
text = " ".join(title for title in df6)

# Creating word_cloud with text as argument in .generate() method
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)

# Display the generated Word Cloud
plt.imshow(word_cloud, interpolation='bilinear')
plt.title("E12 - Natural Language Processing Overview")
plt.axis("off")
plt.show()

# %% [markdown]
# # Exercise 13.2
#
# Evaluate the similarities of the homeworks of the students.
#
# At a homework level, then as a student level.

# %% [markdown]
# # Exercise 13.3
#
# Create a classifier to predict the gender of each student

# %%
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.model_selection import cross_val_score

# use Ramdomforest to predict the star rating
#clf1 = RandomForestClassifier()
#pd.Series(cross_val_score(nb, X1_dtm, y, cv=10)).describe()
#pd.Series(cross_val_score(clf1, X1_dtm, y2, cv=10)).describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-4fdbcceb8bc4> in <module>
#       5 clf1 = RandomForestClassifier()
#       6 #pd.Series(cross_val_score(nb, X1_dtm, y, cv=10)).describe()
# ----> 7 pd.Series(cross_val_score(clf1, X1_dtm, y2, cv=10)).describe()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     399     scorer = check_scoring(estimator, scoring=scoring)
#     400
# --> 401     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     402                                 scoring={'score': scorer}, cv=cv,
#     403                                 n_jobs=n_jobs, verbose=verbose,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     231
#     232     """
# --> 233     X, y, groups = indexable(X, y, groups)
#     234
#     235     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     291     """
#     292     result = [_make_indexable(X) for X in iterables]
# --> 293     check_consistent_length(*result)
#     294     return result
#     295
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     uniques = np.unique(lengths)
#     255     if len(uniques) > 1:
# --> 256         raise ValueError("Found input variables with inconsistent numbers of"
#     257                          " samples: %r" % [int(l) for l in lengths])
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [37, 38]

# %%
# use Naive Bayes to predict the star rating
nb1 = MultinomialNB()
pd.Series(cross_val_score(nb1, X1_dtm, y2, cv=10)).describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-057450d4e2cf> in <module>
#       1 # use Naive Bayes to predict the star rating
#       2 nb1 = MultinomialNB()
# ----> 3 pd.Series(cross_val_score(nb1, X1_dtm, y2, cv=10)).describe()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     399     scorer = check_scoring(estimator, scoring=scoring)
#     400
# --> 401     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     402                                 scoring={'score': scorer}, cv=cv,
#     403                                 n_jobs=n_jobs, verbose=verbose,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     231
#     232     """
# --> 233     X, y, groups = indexable(X, y, groups)
#     234
#     235     cv = check_cv(cv, y, classifier=is_classifier(estimator))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     291     """
#     292     result = [_make_indexable(X) for X in iterables]
# --> 293     check_consistent_length(*result)
#     294     return result
#     295
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     uniques = np.unique(lengths)
#     255     if len(uniques) > 1:
# --> 256         raise ValueError("Found input variables with inconsistent numbers of"
#     257                          " samples: %r" % [int(l) for l in lengths])
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [37, 38]

# %%
# define a function that accepts a vectorizer and calculates the accuracy
def tokenize_test(vect1):
    X1_dtm = vect.fit_transform(X1)
    print('Features: ', X1_dtm.shape[0])
    nb1 = RandomForestClassifier()
    print(pd.Series(cross_val_score(nb, X1_dtm, y2, cv=10)).describe())

# %% [markdown]
# # Stopword Removal

# %%
# remove English stop words
vect1 = CountVectorizer(stop_words='espanish')
tokenize_test(vect1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-36f0fce32024> in <module>
#       1 # remove English stop words
#       2 vect1 = CountVectorizer(stop_words='espanish')
# ----> 3 tokenize_test(vect1)
#
# NameError: name 'tokenize_test' is not defined

# %% [markdown]
# # Exercise 13.4
# Classify group members into different subgroups (minimum 3) according to a characteristic of your choice.
